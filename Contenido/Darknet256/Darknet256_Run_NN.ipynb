# %% [markdown]
# Conexión a Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Prerrequisitos

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pandas as pd
from matplotlib import patches
from tqdm import tqdm
import time
import os

# %% [markdown]
# ## Clonación de darknet

# %%
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet
# !git checkout feature/google-colab
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.
# [Errno 20] Not a directory: 'darknet'
# /content/darknet
# Already on 'feature/google-colab'
# Your branch is up to date with 'origin/feature/google-colab'.

# %% [markdown]
# Este comando compila la arquitectura. Si se desea hacer alguna modificación a los archivos que componen al flujo de Darknet, debe realizarse antes de correr este comando (o volver a correrlo luego de realizar el cambio). De esta manera, la ejecución automática tomará estos archivos.

# %%
# !make
# Out:
# chmod +x *.sh

# %% [markdown]
# Es recomendable a la hora de utilizar Darknet, hacer transfer learning. Esto se debe a su uso para detección de objetos. Inicializar la red con un set de pesos que corresponden a una red que detecta objetos de forma efectiva permite que el tiempo de procesamiento necesario para solucionar el problema se reduzca. Utillizamos los pesos oficiales de Joseph Redmon.

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-07-09 02:52:27--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74    30%[=====>              ]  46.80M   125KB/s    eta 11m 53s^C

# %% [markdown]
# ##Inicialización de las variables de dirección de archivos
# A lo largo del trabajo, se accede a los archivos subidos a Google Drive. Se inicializan como variables para simplificar.

# %%
objdata = '/content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj_data.txt'
yolov3cfg = '/content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/yolo-obj1.cfg'
preweights = '/content/darknet/darknet53.conv.74'

# %% [markdown]
# Durante el entrenamiento, Darknet guarda los pesos actuales cada 100 interaciones en el archivo que llama last_weights y crea un nuevo archivo de pesos cada 1000 interaciones. Esto fue sumamente importante ya que correr una red neuronal en Colab implica que cada 12 hs es necesario reconectar a la GPU a distancia, que si se tienen fluctuaciones en la conexión a internet se desconecta y que posee un límite de uso de GPU por cuenta. Debido a que se contaba con estas instancias intermedias del estado de los pesos, era posible retomar el entrenamiento casi sin pérdida de información e incluso desde otra cuenta con acceso a estos archivos de backup. Aquí se tienen los archivos generados con el entrenamiento de esta notebook:

# %%
backup_dir = '/content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup/'
last_weights = backup_dir + '/yolo-obj1_last.weights'
weights16k = backup_dir + '/yolo-obj1_16000.weights'
weights15k = backup_dir + '/yolo-obj1_15000.weights'
weights14k = backup_dir + '/yolo-obj1_14000.weights'
weights13k = backup_dir + '/yolo-obj1_13000.weights'
weights12k = backup_dir + '/yolo-obj1_12000.weights'
weights11k = backup_dir + '/yolo-obj1_11000.weights'
weights10k = backup_dir + '/yolo-obj1_10000.weights'
weights9k = backup_dir + '/yolo-obj1_9000.weights'
weights8k = backup_dir + '/yolo-obj1_8000.weights'
weights7k = backup_dir + '/yolo-obj1_7000.weights'
weights6k = backup_dir + '/yolo-obj1_6000.weights'
weights5k = backup_dir + '/yolo-obj1_5000.weights'
weights4k = backup_dir + '/yolo-obj1_4000.weights'
weights3k = backup_dir + '/yolo-obj1_3000.weights'
weights2k = backup_dir + '/yolo-obj1_2000.weights'

# %% [markdown]
# # Train

# %% [markdown]
# ## Train with pjreddie's weights

# %%
#!./darknet detector train '$objdata' '$yolov3cfg' '$preweights' -dont_show
# Out:
# yolo-obj1
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32 0.639 BF
#    1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64 3.407 BF
#    2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32 0.379 BF
#    3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128 3.407 BF
#    6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#    7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#   10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   152 x 152 x 128   ->    76 x  76 x 256 3.407 BF
#   13 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   14 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   17 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   20 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   23 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   26 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   29 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   32 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   35 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    76 x  76 x 256   ->    38 x  38 x 512 3.407 BF
#   38 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   39 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   42 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   45 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   48 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   51 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   54 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   57 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   60 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    38 x  38 x 512   ->    19 x  19 x1024 3.407 BF
#   63 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   64 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   67 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   70 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   73 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   76 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   77 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   78 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   79 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   80 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   81 conv     18  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x  18 0.013 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    19 x  19 x 512   ->    19 x  19 x 256 0.095 BF
#   85 upsample            2x    19 x  19 x 256   ->    38 x  38 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    38 x  38 x 768   ->    38 x  38 x 256 0.568 BF
#   88 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   89 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   90 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   91 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   92 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   93 conv     18  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x  18 0.027 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    38 x  38 x 256   ->    38 x  38 x 128 0.095 BF
#   97 upsample            2x    38 x  38 x 128   ->    76 x  76 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    76 x  76 x 384   ->    76 x  76 x 128 0.568 BF
#  100 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  101 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  102 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  103 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  104 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  105 conv     18  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x  18 0.053 BF
#  106 yolo
# Total BFLOPS 139.465
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/darknet/darknet53.conv.74...
#  seen 64
# Done!
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
# Resizing
# 896 x 896

# %% [markdown]
# ## Train with last weights

# %%
# Start training at the point where the last runtime finished
# !./darknet detector train '$objdata' '$yolov3cfg' '$last_weights' -dont_show
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Loaded: 5.495550 seconds
#
#  9441: 0.431140, 0.216198 avg loss, 0.001000 rate, 9.355119 seconds, 604224 images
# Loaded: 0.000050 seconds
#
#  9442: 0.234057, 0.217984 avg loss, 0.001000 rate, 9.486407 seconds, 604288 images
# Loaded: 0.000063 seconds
#
#  9443: 0.278506, 0.224036 avg loss, 0.001000 rate, 9.567285 seconds, 604352 images
# Loaded: 0.000054 seconds
#
#  9444: 0.139955, 0.215628 avg loss, 0.001000 rate, 9.532696 seconds, 604416 images
# Loaded: 0.000056 seconds
#
#  9445: 0.158297, 0.209895 avg loss, 0.001000 rate, 9.468476 seconds, 604480 images
# Loaded: 0.000061 seconds
#
#  9446: 0.156674, 0.204573 avg loss, 0.001000 rate, 9.425771 seconds, 604544 images
# Loaded: 0.000069 seconds
#
#  9447: 0.252582, 0.209374 avg loss, 0.001000 rate, 9.407875 seconds, 604608 images
# Loaded: 0.000063 seconds
#
#  9448: 0.226919, 0.211128 avg loss, 0.001000 rate, 9.420792 seconds, 604672 images
# Loaded: 0.000092 seconds
#
#  9449: 0.152266, 0.205242 avg loss, 0.001000 rate, 9.409878 seconds, 604736 images
# Loaded: 0.000047 seconds
#
#  9450: 0.194246, 0.204142 avg loss, 0.001000 rate, 9.427728 seconds, 604800 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 5.439937 seconds
#
#  9451: 0.170710, 0.200799 avg loss, 0.001000 rate, 18.113661 seconds, 604864 images
# Loaded: 0.000038 seconds
#
#  9452: 0.166697, 0.197389 avg loss, 0.001000 rate, 18.397442 seconds, 604928 images
# Loaded: 0.000069 seconds
#
#  9453: 0.301566, 0.207807 avg loss, 0.001000 rate, 18.177265 seconds, 604992 images
# Loaded: 0.000058 seconds
#
#  9454: 0.148955, 0.201921 avg loss, 0.001000 rate, 18.127141 seconds, 605056 images
# Loaded: 0.000038 seconds
#
#  9455: 0.136857, 0.195415 avg loss, 0.001000 rate, 18.130432 seconds, 605120 images
# Loaded: 0.000057 seconds
#
#  9456: 0.290838, 0.204957 avg loss, 0.001000 rate, 18.197380 seconds, 605184 images
# Loaded: 0.000039 seconds
#
#  9457: 0.227670, 0.207229 avg loss, 0.001000 rate, 18.184236 seconds, 605248 images
# Loaded: 0.000042 seconds
#
#  9458: 0.315092, 0.218015 avg loss, 0.001000 rate, 18.173089 seconds, 605312 images
# Loaded: 0.000033 seconds
#
#  9459: 0.173203, 0.213534 avg loss, 0.001000 rate, 18.165802 seconds, 605376 images
# Loaded: 0.000041 seconds
#
#  9460: 0.254023, 0.217583 avg loss, 0.001000 rate, 18.178057 seconds, 605440 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 4.298088 seconds
#
#  9461: 0.244162, 0.220241 avg loss, 0.001000 rate, 10.115009 seconds, 605504 images
# Loaded: 0.000041 seconds
#
#  9462: 0.276433, 0.225860 avg loss, 0.001000 rate, 10.201728 seconds, 605568 images
# Loaded: 0.000062 seconds
#
#  9463: 0.194295, 0.222703 avg loss, 0.001000 rate, 10.228678 seconds, 605632 images
# Loaded: 0.000082 seconds
#
#  9464: 0.154925, 0.215925 avg loss, 0.001000 rate, 10.165352 seconds, 605696 images
# Loaded: 0.000040 seconds
#
#  9465: 0.171894, 0.211522 avg loss, 0.001000 rate, 10.120288 seconds, 605760 images
# Loaded: 0.000041 seconds
#
#  9466: 0.201101, 0.210480 avg loss, 0.001000 rate, 10.102187 seconds, 605824 images
# Loaded: 0.000049 seconds
#
#  9467: 0.211243, 0.210557 avg loss, 0.001000 rate, 10.096553 seconds, 605888 images
# Loaded: 0.000041 seconds
#
#  9468: 0.161724, 0.205673 avg loss, 0.001000 rate, 10.133456 seconds, 605952 images
# Loaded: 0.000046 seconds
#
#  9469: 0.185566, 0.203663 avg loss, 0.001000 rate, 10.158457 seconds, 606016 images
# Loaded: 0.000065 seconds
#
#  9470: 0.147670, 0.198063 avg loss, 0.001000 rate, 10.202380 seconds, 606080 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 3.452847 seconds
#
#  9471: 0.148468, 0.193104 avg loss, 0.001000 rate, 10.146931 seconds, 606144 images
# Loaded: 0.000073 seconds
#
#  9472: 0.281120, 0.201905 avg loss, 0.001000 rate, 10.169283 seconds, 606208 images
# Loaded: 0.000041 seconds
#
#  9473: 0.122496, 0.193964 avg loss, 0.001000 rate, 10.173786 seconds, 606272 images
# Loaded: 0.000041 seconds
#
#  9474: 0.276881, 0.202256 avg loss, 0.001000 rate, 10.155334 seconds, 606336 images
# Loaded: 0.000065 seconds
#
#  9475: 0.146067, 0.196637 avg loss, 0.001000 rate, 10.143344 seconds, 606400 images
# Loaded: 0.000039 seconds
#
#  9476: 0.190508, 0.196024 avg loss, 0.001000 rate, 10.143696 seconds, 606464 images
# Loaded: 0.000070 seconds
#
#  9477: 0.156261, 0.192048 avg loss, 0.001000 rate, 10.131018 seconds, 606528 images
# Loaded: 0.000048 seconds
#
#  9478: 0.180017, 0.190845 avg loss, 0.001000 rate, 10.148433 seconds, 606592 images
# Loaded: 0.000065 seconds
#
#  9479: 0.195931, 0.191353 avg loss, 0.001000 rate, 10.136309 seconds, 606656 images
# Loaded: 0.000039 seconds
#
#  9480: 0.125678, 0.184786 avg loss, 0.001000 rate, 10.152717 seconds, 606720 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 55.45 MB
#  CUDA allocate done!
# Loaded: 3.132336 seconds
#
#  9481: 0.181203, 0.184428 avg loss, 0.001000 rate, 10.907041 seconds, 606784 images
# Loaded: 0.000045 seconds
#
#  9482: 0.198637, 0.185848 avg loss, 0.001000 rate, 11.037098 seconds, 606848 images
# Loaded: 0.000058 seconds
#
#  9483: 0.181569, 0.185421 avg loss, 0.001000 rate, 11.080691 seconds, 606912 images
# Loaded: 0.000055 seconds
#
#  9484: 0.158675, 0.182746 avg loss, 0.001000 rate, 11.031808 seconds, 606976 images
# Loaded: 0.000065 seconds
#
#  9485: 0.244594, 0.188931 avg loss, 0.001000 rate, 10.991937 seconds, 607040 images
# Loaded: 0.000053 seconds
#
#  9486: 0.120317, 0.182069 avg loss, 0.001000 rate, 10.959463 seconds, 607104 images
# Loaded: 0.000066 seconds
#
#  9487: 0.222001, 0.186063 avg loss, 0.001000 rate, 10.959473 seconds, 607168 images
# Loaded: 0.000046 seconds
#
#  9488: 0.120404, 0.179497 avg loss, 0.001000 rate, 11.007984 seconds, 607232 images
# Loaded: 0.000070 seconds
#
#  9489: 0.182105, 0.179758 avg loss, 0.001000 rate, 11.014832 seconds, 607296 images
# Loaded: 0.000054 seconds
#
#  9490: 0.180038, 0.179786 avg loss, 0.001000 rate, 11.037953 seconds, 607360 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 2.711402 seconds
#
#  9491: 0.244218, 0.186229 avg loss, 0.001000 rate, 20.510852 seconds, 607424 images
# Loaded: 0.000048 seconds
#
#  9492: 0.182102, 0.185816 avg loss, 0.001000 rate, 20.719208 seconds, 607488 images
# Loaded: 0.000035 seconds
#
#  9493: 0.178535, 0.185088 avg loss, 0.001000 rate, 20.627018 seconds, 607552 images
# Loaded: 0.000040 seconds
#
#  9494: 0.221255, 0.188705 avg loss, 0.001000 rate, 20.639898 seconds, 607616 images
# Loaded: 0.000049 seconds
#
#  9495: 0.164537, 0.186288 avg loss, 0.001000 rate, 20.590901 seconds, 607680 images
# Loaded: 0.000064 seconds
#
#  9496: 0.145602, 0.182219 avg loss, 0.001000 rate, 20.671012 seconds, 607744 images
# Loaded: 0.000031 seconds
#
#  9497: 0.182485, 0.182246 avg loss, 0.001000 rate, 20.649957 seconds, 607808 images
# Loaded: 0.000047 seconds
#
#  9498: 0.204137, 0.184435 avg loss, 0.001000 rate, 20.687074 seconds, 607872 images
# Loaded: 0.000062 seconds
#
#  9499: 0.233839, 0.189375 avg loss, 0.001000 rate, 20.692682 seconds, 607936 images
# Loaded: 0.000069 seconds
#
#  9500: 0.235035, 0.193941 avg loss, 0.001000 rate, 20.695390 seconds, 608000 images
# Saving weights to /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_last.weights
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 5.001782 seconds
#
#  9501: 0.269723, 0.201520 avg loss, 0.001000 rate, 20.513920 seconds, 608064 images
# Loaded: 0.000042 seconds
#
#  9502: 0.230405, 0.204408 avg loss, 0.001000 rate, 20.816371 seconds, 608128 images
# Loaded: 0.000043 seconds
#
#  9503: 0.269057, 0.210873 avg loss, 0.001000 rate, 20.589591 seconds, 608192 images
# Loaded: 0.000050 seconds
#
#  9504: 0.143096, 0.204095 avg loss, 0.001000 rate, 20.611386 seconds, 608256 images
# Loaded: 0.000045 seconds
#
#  9505: 0.237729, 0.207459 avg loss, 0.001000 rate, 20.679632 seconds, 608320 images
# Loaded: 0.000040 seconds
#
#  9506: 0.179485, 0.204661 avg loss, 0.001000 rate, 20.694099 seconds, 608384 images
# Loaded: 0.000066 seconds
#
#  9507: 0.289990, 0.213194 avg loss, 0.001000 rate, 20.647887 seconds, 608448 images
# Loaded: 0.000033 seconds
#
#  9508: 0.176537, 0.209528 avg loss, 0.001000 rate, 20.631720 seconds, 608512 images
# Loaded: 0.000065 seconds
#
#  9509: 0.283281, 0.216904 avg loss, 0.001000 rate, 20.679834 seconds, 608576 images
# Loaded: 0.000044 seconds
#
#  9510: 0.239822, 0.219196 avg loss, 0.001000 rate, 20.718876 seconds, 608640 images
# Resizing
# 768 x 768
#  try to allocate additional workspace_size = 88.48 MB
#  CUDA allocate done!
# Loaded: 3.464520 seconds
#
#  9511: 0.099968, 0.207273 avg loss, 0.001000 rate, 16.171030 seconds, 608704 images
# Loaded: 0.000043 seconds
#
#  9512: 0.151517, 0.201697 avg loss, 0.001000 rate, 16.336582 seconds, 608768 images
# Loaded: 0.000053 seconds
#
#  9513: 0.286851, 0.210213 avg loss, 0.001000 rate, 16.254342 seconds, 608832 images
# Loaded: 0.000031 seconds
#
#  9514: 0.206245, 0.209816 avg loss, 0.001000 rate, 16.203106 seconds, 608896 images
# Loaded: 0.000040 seconds
#
#  9515: 0.219810, 0.210815 avg loss, 0.001000 rate, 16.181546 seconds, 608960 images
# Loaded: 0.000050 seconds
#
#  9516: 0.246911, 0.214425 avg loss, 0.001000 rate, 16.232445 seconds, 609024 images
# Loaded: 0.000074 seconds
#
#  9517: 0.237957, 0.216778 avg loss, 0.001000 rate, 16.244536 seconds, 609088 images
# Loaded: 0.000079 seconds
#
#  9518: 0.223916, 0.217492 avg loss, 0.001000 rate, 16.263528 seconds, 609152 images
# Loaded: 0.000050 seconds
#
#  9519: 0.207205, 0.216463 avg loss, 0.001000 rate, 16.236524 seconds, 609216 images
# Loaded: 0.000038 seconds
#
#  9520: 0.223032, 0.217120 avg loss, 0.001000 rate, 16.239407 seconds, 609280 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 3.156657 seconds
#
#  9521: 0.210233, 0.216431 avg loss, 0.001000 rate, 20.562907 seconds, 609344 images
# Loaded: 0.000037 seconds
#
#  9522: 0.236173, 0.218405 avg loss, 0.001000 rate, 20.798131 seconds, 609408 images
# Loaded: 0.000048 seconds
#
#  9523: 0.186305, 0.215195 avg loss, 0.001000 rate, 20.605640 seconds, 609472 images
# Loaded: 0.000040 seconds
#
#  9524: 0.206502, 0.214326 avg loss, 0.001000 rate, 20.609482 seconds, 609536 images
# Loaded: 0.000044 seconds
#
#  9525: 0.235921, 0.216486 avg loss, 0.001000 rate, 20.687048 seconds, 609600 images
# Loaded: 0.000032 seconds
#
#  9526: 0.176218, 0.212459 avg loss, 0.001000 rate, 20.685814 seconds, 609664 images
# Loaded: 0.000048 seconds
#
#  9527: 0.367034, 0.227916 avg loss, 0.001000 rate, 20.637588 seconds, 609728 images
# Loaded: 0.000048 seconds
#
#  9528: 0.164976, 0.221622 avg loss, 0.001000 rate, 20.625764 seconds, 609792 images
# Loaded: 0.000063 seconds
#
#  9529: 0.265676, 0.226028 avg loss, 0.001000 rate, 20.664420 seconds, 609856 images
# Loaded: 0.000047 seconds
#
#  9530: 0.148085, 0.218233 avg loss, 0.001000 rate, 20.708441 seconds, 609920 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 74.35 MB
#  CUDA allocate done!
# Loaded: 2.553075 seconds
#
#  9531: 0.145738, 0.210984 avg loss, 0.001000 rate, 13.868146 seconds, 609984 images
# Loaded: 0.000054 seconds
#
#  9532: 0.271953, 0.217081 avg loss, 0.001000 rate, 13.989722 seconds, 610048 images
# Loaded: 0.000034 seconds
#
#  9533: 0.229279, 0.218301 avg loss, 0.001000 rate, 13.920344 seconds, 610112 images
# Loaded: 0.000042 seconds
#
#  9534: 0.178247, 0.214295 avg loss, 0.001000 rate, 13.920277 seconds, 610176 images
# Loaded: 0.000070 seconds
#
#  9535: 0.210514, 0.213917 avg loss, 0.001000 rate, 13.903674 seconds, 610240 images
# Loaded: 0.000035 seconds
#
#  9536: 0.213981, 0.213924 avg loss, 0.001000 rate, 13.903494 seconds, 610304 images
# Loaded: 0.000046 seconds
#
#  9537: 0.117494, 0.204281 avg loss, 0.001000 rate, 13.875885 seconds, 610368 images
# Loaded: 0.000032 seconds
#
#  9538: 0.218787, 0.205731 avg loss, 0.001000 rate, 13.883178 seconds, 610432 images
# Loaded: 0.000054 seconds
#
#  9539: 0.198629, 0.205021 avg loss, 0.001000 rate, 13.866878 seconds, 610496 images
# Loaded: 0.000042 seconds
#
#  9540: 0.198467, 0.204366 avg loss, 0.001000 rate, 13.911844 seconds, 610560 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 3.039560 seconds
#
#  9541: 0.287729, 0.212702 avg loss, 0.001000 rate, 20.474673 seconds, 610624 images
# Loaded: 0.000046 seconds
#
#  9542: 0.327089, 0.224141 avg loss, 0.001000 rate, 20.741518 seconds, 610688 images
# Loaded: 0.000042 seconds
#
#  9543: 0.168998, 0.218626 avg loss, 0.001000 rate, 20.648894 seconds, 610752 images
# Loaded: 0.000037 seconds
#
#  9544: 0.186449, 0.215409 avg loss, 0.001000 rate, 20.610068 seconds, 610816 images
# Loaded: 0.000036 seconds
#
#  9545: 0.250963, 0.218964 avg loss, 0.001000 rate, 20.635158 seconds, 610880 images
# Loaded: 0.000038 seconds
#
#  9546: 0.181644, 0.215232 avg loss, 0.001000 rate, 20.718426 seconds, 610944 images
# Loaded: 0.000065 seconds
#
#  9547: 0.174602, 0.211169 avg loss, 0.001000 rate, 20.702835 seconds, 611008 images
# Loaded: 0.000039 seconds
#
#  9548: 0.279363, 0.217989 avg loss, 0.001000 rate, 20.688560 seconds, 611072 images
# Loaded: 0.000043 seconds
#
#  9549: 0.171949, 0.213385 avg loss, 0.001000 rate, 20.687265 seconds, 611136 images
# Loaded: 0.000082 seconds
#
#  9550: 0.262971, 0.218343 avg loss, 0.001000 rate, 20.720106 seconds, 611200 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 74.35 MB
#  CUDA allocate done!
# Loaded: 3.250639 seconds
#
#  9551: 0.176883, 0.214197 avg loss, 0.001000 rate, 13.841411 seconds, 611264 images
# Loaded: 0.000063 seconds
#
#  9552: 0.124857, 0.205263 avg loss, 0.001000 rate, 13.892096 seconds, 611328 images
# Loaded: 0.000044 seconds
#
#  9553: 0.162549, 0.200992 avg loss, 0.001000 rate, 13.875731 seconds, 611392 images
# Loaded: 0.000062 seconds
#
#  9554: 0.130407, 0.193933 avg loss, 0.001000 rate, 13.889857 seconds, 611456 images
# Loaded: 0.000037 seconds
#
#  9555: 0.129679, 0.187508 avg loss, 0.001000 rate, 13.885863 seconds, 611520 images
# Loaded: 0.000063 seconds
#
#  9556: 0.148300, 0.183587 avg loss, 0.001000 rate, 13.940353 seconds, 611584 images
# Loaded: 0.000039 seconds
#
#  9557: 0.287753, 0.194004 avg loss, 0.001000 rate, 13.926536 seconds, 611648 images
# Loaded: 0.000043 seconds
#
#  9558: 0.143045, 0.188908 avg loss, 0.001000 rate, 13.926533 seconds, 611712 images
# Loaded: 0.000071 seconds
#
#  9559: 0.166903, 0.186707 avg loss, 0.001000 rate, 13.910194 seconds, 611776 images
# Loaded: 0.000040 seconds
#
#  9560: 0.132918, 0.181328 avg loss, 0.001000 rate, 13.939078 seconds, 611840 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 2.996194 seconds
#
#  9561: 0.175129, 0.180708 avg loss, 0.001000 rate, 15.114825 seconds, 611904 images
# Loaded: 0.000071 seconds
#
#  9562: 0.118867, 0.174524 avg loss, 0.001000 rate, 15.230456 seconds, 611968 images
# Loaded: 0.000041 seconds
#
#  9563: 0.225865, 0.179658 avg loss, 0.001000 rate, 15.248090 seconds, 612032 images
# Loaded: 0.000035 seconds
#
#  9564: 0.227185, 0.184411 avg loss, 0.001000 rate, 15.266682 seconds, 612096 images
# Loaded: 0.000056 seconds
#
#  9565: 0.233011, 0.189271 avg loss, 0.001000 rate, 15.258380 seconds, 612160 images
# Loaded: 0.000045 seconds
#
#  9566: 0.178557, 0.188200 avg loss, 0.001000 rate, 15.261614 seconds, 612224 images
# Loaded: 0.000051 seconds
#
#  9567: 0.308981, 0.200278 avg loss, 0.001000 rate, 15.269598 seconds, 612288 images
# Loaded: 0.000039 seconds
#
#  9568: 0.196655, 0.199916 avg loss, 0.001000 rate, 15.270330 seconds, 612352 images
# Loaded: 0.000060 seconds
#
#  9569: 0.157775, 0.195702 avg loss, 0.001000 rate, 15.273289 seconds, 612416 images
# Loaded: 0.000063 seconds
#
#  9570: 0.230545, 0.199186 avg loss, 0.001000 rate, 15.300787 seconds, 612480 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 2.717075 seconds
#
#  9571: 0.244438, 0.203711 avg loss, 0.001000 rate, 15.174025 seconds, 612544 images
# Loaded: 0.000047 seconds
#
#  9572: 0.142620, 0.197602 avg loss, 0.001000 rate, 15.290621 seconds, 612608 images
# Loaded: 0.000048 seconds
#
#  9573: 0.136222, 0.191464 avg loss, 0.001000 rate, 15.246462 seconds, 612672 images
# Loaded: 0.000063 seconds
#
#  9574: 0.232453, 0.195563 avg loss, 0.001000 rate, 15.240381 seconds, 612736 images
# Loaded: 0.000041 seconds
#
#  9575: 0.181883, 0.194195 avg loss, 0.001000 rate, 15.183792 seconds, 612800 images
# Loaded: 0.000036 seconds
#
#  9576: 0.238075, 0.198583 avg loss, 0.001000 rate, 15.221548 seconds, 612864 images
# Loaded: 0.000042 seconds
#
#  9577: 0.167163, 0.195441 avg loss, 0.001000 rate, 15.212013 seconds, 612928 images
# Loaded: 0.000042 seconds
#
#  9578: 0.223417, 0.198238 avg loss, 0.001000 rate, 15.236338 seconds, 612992 images
# Loaded: 0.000044 seconds
#
#  9579: 0.251344, 0.203549 avg loss, 0.001000 rate, 15.225398 seconds, 613056 images
# Loaded: 0.000039 seconds
#
#  9580: 0.210003, 0.204194 avg loss, 0.001000 rate, 15.241445 seconds, 613120 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 4.093781 seconds
#
#  9581: 0.131973, 0.196972 avg loss, 0.001000 rate, 10.113523 seconds, 613184 images
# Loaded: 0.000044 seconds
#
#  9582: 0.197068, 0.196982 avg loss, 0.001000 rate, 10.201597 seconds, 613248 images
# Loaded: 0.000051 seconds
#
#  9583: 0.223096, 0.199593 avg loss, 0.001000 rate, 10.275107 seconds, 613312 images
# Loaded: 0.000057 seconds
#
#  9584: 0.233037, 0.202938 avg loss, 0.001000 rate, 10.195642 seconds, 613376 images
# Loaded: 0.000034 seconds
#
#  9585: 0.138440, 0.196488 avg loss, 0.001000 rate, 10.134005 seconds, 613440 images
# Loaded: 0.000042 seconds
#
#  9586: 0.204225, 0.197262 avg loss, 0.001000 rate, 10.121186 seconds, 613504 images
# Loaded: 0.000058 seconds
#
#  9587: 0.124132, 0.189949 avg loss, 0.001000 rate, 10.099908 seconds, 613568 images
# Loaded: 0.000063 seconds
#
#  9588: 0.157878, 0.186742 avg loss, 0.001000 rate, 10.130956 seconds, 613632 images
# Loaded: 0.000055 seconds
#
#  9589: 0.209110, 0.188978 avg loss, 0.001000 rate, 10.128714 seconds, 613696 images
# Loaded: 0.000069 seconds
#
#  9590: 0.172311, 0.187312 avg loss, 0.001000 rate, 10.163690 seconds, 613760 images
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 2.419635 seconds
#
#  9591: 0.127941, 0.181375 avg loss, 0.001000 rate, 12.927423 seconds, 613824 images
# Loaded: 0.000046 seconds
#
#  9592: 0.251665, 0.188404 avg loss, 0.001000 rate, 13.065785 seconds, 613888 images
# Loaded: 0.000063 seconds
#
#  9593: 0.233584, 0.192922 avg loss, 0.001000 rate, 12.967609 seconds, 613952 images
# Loaded: 0.000066 seconds
#
#  9594: 0.173992, 0.191029 avg loss, 0.001000 rate, 12.966566 seconds, 614016 images
# Loaded: 0.000065 seconds
#
#  9595: 0.123293, 0.184255 avg loss, 0.001000 rate, 12.951916 seconds, 614080 images
# Loaded: 0.000038 seconds
#
#  9596: 0.209433, 0.186773 avg loss, 0.001000 rate, 12.962634 seconds, 614144 images
# Loaded: 0.000040 seconds
#
#  9597: 0.150927, 0.183188 avg loss, 0.001000 rate, 12.976973 seconds, 614208 images
# Loaded: 0.000034 seconds
#
#  9598: 0.188182, 0.183688 avg loss, 0.001000 rate, 13.026513 seconds, 614272 images
# Loaded: 0.000038 seconds
#
#  9599: 0.218867, 0.187206 avg loss, 0.001000 rate, 12.982100 seconds, 614336 images
# Loaded: 0.000066 seconds
#
#  9600: 0.144644, 0.182950 avg loss, 0.001000 rate, 12.989070 seconds, 614400 images
# Saving weights to /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_last.weights
# Resizing
# 640 x 640
#  try to allocate additional workspace_size = 61.44 MB
#  CUDA allocate done!
# Loaded: 3.767252 seconds
#
#  9601: 0.108342, 0.175489 avg loss, 0.001000 rate, 11.627092 seconds, 614464 images
# Loaded: 0.000043 seconds
#
#  9602: 0.144351, 0.172375 avg loss, 0.001000 rate, 11.768441 seconds, 614528 images
# Loaded: 0.000043 seconds
#
#  9603: 0.153455, 0.170483 avg loss, 0.001000 rate, 11.768675 seconds, 614592 images
# Loaded: 0.000066 seconds
#
#  9604: 0.200049, 0.173440 avg loss, 0.001000 rate, 11.718320 seconds, 614656 images
# Loaded: 0.000072 seconds
#
#  9605: 0.247362, 0.180832 avg loss, 0.001000 rate, 11.680109 seconds, 614720 images
# Loaded: 0.000073 seconds
#
#  9606: 0.164743, 0.179223 avg loss, 0.001000 rate, 11.677053 seconds, 614784 images
# Loaded: 0.000055 seconds
#
#  9607: 0.243323, 0.185633 avg loss, 0.001000 rate, 11.684663 seconds, 614848 images
# Loaded: 0.000053 seconds
#
#  9608: 0.147516, 0.181821 avg loss, 0.001000 rate, 11.707613 seconds, 614912 images
# Loaded: 0.000073 seconds
#
#  9609: 0.257040, 0.189343 avg loss, 0.001000 rate, 11.727410 seconds, 614976 images
# Loaded: 0.000045 seconds
#
#  9610: 0.201554, 0.190564 avg loss, 0.001000 rate, 11.715536 seconds, 615040 images
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 2.486800 seconds
#
#  9611: 0.294398, 0.200948 avg loss, 0.001000 rate, 12.983347 seconds, 615104 images
# Loaded: 0.000043 seconds
#
#  9612: 0.258835, 0.206736 avg loss, 0.001000 rate, 12.971919 seconds, 615168 images
# Loaded: 0.000053 seconds
#
#  9613: 0.210911, 0.207154 avg loss, 0.001000 rate, 12.989199 seconds, 615232 images
# Loaded: 0.000070 seconds
#
#  9614: 0.247203, 0.211159 avg loss, 0.001000 rate, 12.986106 seconds, 615296 images
# Loaded: 0.000038 seconds
#
#  9615: 0.230777, 0.213121 avg loss, 0.001000 rate, 12.978342 seconds, 615360 images
# Loaded: 0.000049 seconds
#
#  9616: 0.100704, 0.201879 avg loss, 0.001000 rate, 12.971399 seconds, 615424 images
# Loaded: 0.000041 seconds
#
#  9617: 0.084722, 0.190163 avg loss, 0.001000 rate, 12.956919 seconds, 615488 images
# Loaded: 0.000038 seconds
#
#  9618: 0.200414, 0.191188 avg loss, 0.001000 rate, 12.963851 seconds, 615552 images
# Loaded: 0.000083 seconds
#
#  9619: 0.260485, 0.198118 avg loss, 0.001000 rate, 12.979403 seconds, 615616 images
# Loaded: 0.000042 seconds
#
#  9620: 0.223348, 0.200641 avg loss, 0.001000 rate, 12.968837 seconds, 615680 images
# Resizing
# 640 x 640
#  try to allocate additional workspace_size = 61.44 MB
#  CUDA allocate done!
# Loaded: 3.598185 seconds
#
#  9621: 0.263798, 0.206957 avg loss, 0.001000 rate, 11.667779 seconds, 615744 images
# Loaded: 0.000042 seconds
#
#  9622: 0.260909, 0.212352 avg loss, 0.001000 rate, 11.769737 seconds, 615808 images
# Loaded: 0.000063 seconds
#
#  9623: 0.226921, 0.213809 avg loss, 0.001000 rate, 11.804676 seconds, 615872 images
# Loaded: 0.000061 seconds
#
#  9624: 0.126282, 0.205056 avg loss, 0.001000 rate, 11.713667 seconds, 615936 images
# Loaded: 0.000033 seconds
#
#  9625: 0.201908, 0.204741 avg loss, 0.001000 rate, 11.683205 seconds, 616000 images
# Loaded: 0.000046 seconds
#
#  9626: 0.343354, 0.218603 avg loss, 0.001000 rate, 11.697622 seconds, 616064 images
# Loaded: 0.000069 seconds
#
#  9627: 0.104371, 0.207179 avg loss, 0.001000 rate, 11.670162 seconds, 616128 images
# Loaded: 0.000088 seconds
#
#  9628: 0.189414, 0.205403 avg loss, 0.001000 rate, 11.699574 seconds, 616192 images
# Loaded: 0.000066 seconds
#
#  9629: 0.198778, 0.204740 avg loss, 0.001000 rate, 11.720969 seconds, 616256 images
# Loaded: 0.000063 seconds
#
#  9630: 0.157390, 0.200005 avg loss, 0.001000 rate, 11.714516 seconds, 616320 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 4.824413 seconds
#
#  9631: 0.279760, 0.207981 avg loss, 0.001000 rate, 20.543007 seconds, 616384 images
# Loaded: 0.000050 seconds
#
#  9632: 0.293931, 0.216576 avg loss, 0.001000 rate, 20.830809 seconds, 616448 images
# Loaded: 0.000068 seconds
#
#  9633: 0.178881, 0.212806 avg loss, 0.001000 rate, 20.589793 seconds, 616512 images
# Loaded: 0.000054 seconds
#
#  9634: 0.226523, 0.214178 avg loss, 0.001000 rate, 20.567958 seconds, 616576 images
# Loaded: 0.000067 seconds
#
#  9635: 0.188340, 0.211594 avg loss, 0.001000 rate, 20.670324 seconds, 616640 images
# Loaded: 0.000047 seconds
#
#  9636: 0.209070, 0.211342 avg loss, 0.001000 rate, 20.719009 seconds, 616704 images
# Loaded: 0.000061 seconds
#
#  9637: 0.101295, 0.200337 avg loss, 0.001000 rate, 20.626283 seconds, 616768 images
# Loaded: 0.000052 seconds
#
#  9638: 0.146869, 0.194990 avg loss, 0.001000 rate, 20.623011 seconds, 616832 images
# Loaded: 0.000054 seconds
#
#  9639: 0.261968, 0.201688 avg loss, 0.001000 rate, 20.620703 seconds, 616896 images
# Loaded: 0.000072 seconds
#
#  9640: 0.258250, 0.207344 avg loss, 0.001000 rate, 20.673161 seconds, 616960 images
# Resizing
# 768 x 768
#  try to allocate additional workspace_size = 88.48 MB
#  CUDA allocate done!
# Loaded: 3.624066 seconds
#
#  9641: 0.274109, 0.214021 avg loss, 0.001000 rate, 16.153616 seconds, 617024 images
# Loaded: 0.000069 seconds
#
#  9642: 0.296844, 0.222303 avg loss, 0.001000 rate, 16.341996 seconds, 617088 images
# Loaded: 0.000053 seconds
#
#  9643: 0.268909, 0.226964 avg loss, 0.001000 rate, 16.246756 seconds, 617152 images
# Loaded: 0.000077 seconds
#
#  9644: 0.212641, 0.225531 avg loss, 0.001000 rate, 16.200035 seconds, 617216 images
# Loaded: 0.000058 seconds
#
#  9645: 0.197398, 0.222718 avg loss, 0.001000 rate, 16.181723 seconds, 617280 images
# Loaded: 0.000033 seconds
#
#  9646: 0.167479, 0.217194 avg loss, 0.001000 rate, 16.260013 seconds, 617344 images
# Loaded: 0.000044 seconds
#
#  9647: 0.246245, 0.220099 avg loss, 0.001000 rate, 16.282564 seconds, 617408 images
# Loaded: 0.000034 seconds
#
#  9648: 0.242748, 0.222364 avg loss, 0.001000 rate, 16.232527 seconds, 617472 images
# Loaded: 0.000061 seconds
#
#  9649: 0.297609, 0.229889 avg loss, 0.001000 rate, 16.219185 seconds, 617536 images
# Loaded: 0.000092 seconds
#
#  9650: 0.146928, 0.221593 avg loss, 0.001000 rate, 16.219475 seconds, 617600 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 74.35 MB
#  CUDA allocate done!
# Loaded: 3.186734 seconds
#
#  9651: 0.150798, 0.214513 avg loss, 0.001000 rate, 13.895272 seconds, 617664 images
# Loaded: 0.000046 seconds
#
#  9652: 0.257924, 0.218854 avg loss, 0.001000 rate, 13.970500 seconds, 617728 images
# Loaded: 0.000067 seconds
#
#  9653: 0.274694, 0.224438 avg loss, 0.001000 rate, 13.963629 seconds, 617792 images
# Loaded: 0.000038 seconds
#
#  9654: 0.189791, 0.220973 avg loss, 0.001000 rate, 13.872364 seconds, 617856 images
# Loaded: 0.000048 seconds
#
#  9655: 0.183239, 0.217200 avg loss, 0.001000 rate, 13.868040 seconds, 617920 images
# Loaded: 0.000031 seconds
#
#  9656: 0.176438, 0.213124 avg loss, 0.001000 rate, 13.905210 seconds, 617984 images
# Loaded: 0.000040 seconds
#
#  9657: 0.231095, 0.214921 avg loss, 0.001000 rate, 13.918942 seconds, 618048 images
# Loaded: 0.000035 seconds
#
#  9658: 0.136592, 0.207088 avg loss, 0.001000 rate, 13.932935 seconds, 618112 images
# Loaded: 0.000034 seconds
#
#  9659: 0.162430, 0.202622 avg loss, 0.001000 rate, 13.890671 seconds, 618176 images
# Loaded: 0.000046 seconds
#
#  9660: 0.142435, 0.196604 avg loss, 0.001000 rate, 13.909690 seconds, 618240 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 2.889962 seconds
#
#  9661: 0.108025, 0.187746 avg loss, 0.001000 rate, 19.254683 seconds, 618304 images
# Loaded: 0.000037 seconds
#
#  9662: 0.312612, 0.200232 avg loss, 0.001000 rate, 19.528444 seconds, 618368 images
# Loaded: 0.000047 seconds
#
#  9663: 0.171391, 0.197348 avg loss, 0.001000 rate, 19.359826 seconds, 618432 images
# Loaded: 0.000052 seconds
#
#  9664: 0.116373, 0.189251 avg loss, 0.001000 rate, 19.289556 seconds, 618496 images
# Loaded: 0.000055 seconds
#
#  9665: 0.156056, 0.185931 avg loss, 0.001000 rate, 19.335395 seconds, 618560 images
# Loaded: 0.000052 seconds
#
#  9666: 0.165952, 0.183933 avg loss, 0.001000 rate, 19.458805 seconds, 618624 images
# Loaded: 0.000050 seconds
#
#  9667: 0.090400, 0.174580 avg loss, 0.001000 rate, 19.407356 seconds, 618688 images
# Loaded: 0.000056 seconds
#
#  9668: 0.191281, 0.176250 avg loss, 0.001000 rate, 19.356501 seconds, 618752 images
# Loaded: 0.000041 seconds
#
#  9669: 0.256272, 0.184252 avg loss, 0.001000 rate, 19.382770 seconds, 618816 images
# Loaded: 0.000056 seconds
#
#  9670: 0.126086, 0.178436 avg loss, 0.001000 rate, 19.415307 seconds, 618880 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.641354 seconds
#
#  9671: 0.242524, 0.184844 avg loss, 0.001000 rate, 7.524612 seconds, 618944 images
# Loaded: 0.000040 seconds
#
#  9672: 0.194715, 0.185831 avg loss, 0.001000 rate, 7.564245 seconds, 619008 images
# Loaded: 0.000062 seconds
#
#  9673: 0.220717, 0.189320 avg loss, 0.001000 rate, 7.613126 seconds, 619072 images
# Loaded: 0.000065 seconds
#
#  9674: 0.183776, 0.188766 avg loss, 0.001000 rate, 7.605283 seconds, 619136 images
# Loaded: 0.000035 seconds
#
#  9675: 0.215480, 0.191437 avg loss, 0.001000 rate, 7.560628 seconds, 619200 images
# Loaded: 0.000072 seconds
#
#  9676: 0.116027, 0.183896 avg loss, 0.001000 rate, 7.557877 seconds, 619264 images
# Loaded: 0.000071 seconds
#
#  9677: 0.127932, 0.178300 avg loss, 0.001000 rate, 7.537546 seconds, 619328 images
# Loaded: 0.000037 seconds
#
#  9678: 0.216610, 0.182131 avg loss, 0.001000 rate, 7.541577 seconds, 619392 images
# Loaded: 0.000066 seconds
#
#  9679: 0.225991, 0.186517 avg loss, 0.001000 rate, 7.529789 seconds, 619456 images
# Loaded: 0.000059 seconds
#
#  9680: 0.219664, 0.189831 avg loss, 0.001000 rate, 7.557796 seconds, 619520 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.555454 seconds
#
#  9681: 0.171385, 0.187987 avg loss, 0.001000 rate, 7.559190 seconds, 619584 images
# Loaded: 0.000075 seconds
#
#  9682: 0.193015, 0.188490 avg loss, 0.001000 rate, 7.611965 seconds, 619648 images
# Loaded: 0.000078 seconds
#
#  9683: 0.166074, 0.186248 avg loss, 0.001000 rate, 7.608350 seconds, 619712 images
# Loaded: 0.000037 seconds
#
#  9684: 0.212931, 0.188916 avg loss, 0.001000 rate, 7.614915 seconds, 619776 images
# Loaded: 0.000066 seconds
#
#  9685: 0.230922, 0.193117 avg loss, 0.001000 rate, 7.586416 seconds, 619840 images
# Loaded: 0.000043 seconds
#
#  9686: 0.201858, 0.193991 avg loss, 0.001000 rate, 7.560458 seconds, 619904 images
# Loaded: 0.000065 seconds
#
#  9687: 0.212944, 0.195886 avg loss, 0.001000 rate, 7.582729 seconds, 619968 images
# Loaded: 0.000052 seconds
#
#  9688: 0.193584, 0.195656 avg loss, 0.001000 rate, 7.531347 seconds, 620032 images
# Loaded: 0.000042 seconds
#
#  9689: 0.146960, 0.190786 avg loss, 0.001000 rate, 7.539443 seconds, 620096 images
# Loaded: 0.000053 seconds
#
#  9690: 0.257372, 0.197445 avg loss, 0.001000 rate, 7.556419 seconds, 620160 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 2.083840 seconds
#
#  9691: 0.213968, 0.199097 avg loss, 0.001000 rate, 18.093124 seconds, 620224 images
# Loaded: 0.000067 seconds
#
#  9692: 0.153728, 0.194560 avg loss, 0.001000 rate, 18.323126 seconds, 620288 images
# Loaded: 0.000042 seconds
#
#  9693: 0.188929, 0.193997 avg loss, 0.001000 rate, 18.179283 seconds, 620352 images
# Loaded: 0.000042 seconds
#
#  9694: 0.228122, 0.197410 avg loss, 0.001000 rate, 18.158077 seconds, 620416 images
# Loaded: 0.000047 seconds
#
#  9695: 0.247346, 0.202403 avg loss, 0.001000 rate, 18.173974 seconds, 620480 images
# Loaded: 0.000059 seconds
#
#  9696: 0.221227, 0.204286 avg loss, 0.001000 rate, 18.210667 seconds, 620544 images
# Loaded: 0.000040 seconds
#
#  9697: 0.191539, 0.203011 avg loss, 0.001000 rate, 18.165168 seconds, 620608 images
# Loaded: 0.000043 seconds
#
#  9698: 0.175523, 0.200262 avg loss, 0.001000 rate, 18.165039 seconds, 620672 images
# Loaded: 0.000070 seconds
#
#  9699: 0.173503, 0.197586 avg loss, 0.001000 rate, 18.172311 seconds, 620736 images
# Loaded: 0.000033 seconds
#
#  9700: 0.267636, 0.204591 avg loss, 0.001000 rate, 18.156165 seconds, 620800 images
# Saving weights to /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_last.weights
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.726325 seconds
#
#  9701: 0.187444, 0.202877 avg loss, 0.001000 rate, 10.096543 seconds, 620864 images
# Loaded: 0.000066 seconds
#
#  9702: 0.222607, 0.204850 avg loss, 0.001000 rate, 10.200884 seconds, 620928 images
# Loaded: 0.000070 seconds
#
#  9703: 0.124093, 0.196774 avg loss, 0.001000 rate, 10.242498 seconds, 620992 images
# Loaded: 0.000049 seconds
#
#  9704: 0.164602, 0.193557 avg loss, 0.001000 rate, 10.186201 seconds, 621056 images
# Loaded: 0.000062 seconds
#
#  9705: 0.221930, 0.196394 avg loss, 0.001000 rate, 10.148722 seconds, 621120 images
# Loaded: 0.000067 seconds
#
#  9706: 0.211038, 0.197858 avg loss, 0.001000 rate, 10.130793 seconds, 621184 images
# Loaded: 0.000034 seconds
#
#  9707: 0.233969, 0.201469 avg loss, 0.001000 rate, 10.113152 seconds, 621248 images
# Loaded: 0.000046 seconds
#
#  9708: 0.179561, 0.199279 avg loss, 0.001000 rate, 10.131160 seconds, 621312 images
# Loaded: 0.000049 seconds
#
#  9709: 0.091460, 0.188497 avg loss, 0.001000 rate, 10.160264 seconds, 621376 images
# Loaded: 0.000031 seconds
#
#  9710: 0.262658, 0.195913 avg loss, 0.001000 rate, 10.180554 seconds, 621440 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 2.305787 seconds
#
#  9711: 0.220234, 0.198345 avg loss, 0.001000 rate, 10.130348 seconds, 621504 images
# Loaded: 0.000060 seconds
#
#  9712: 0.235525, 0.202063 avg loss, 0.001000 rate, 10.180422 seconds, 621568 images
# Loaded: 0.000068 seconds
#
#  9713: 0.150780, 0.196935 avg loss, 0.001000 rate, 10.174108 seconds, 621632 images
# Loaded: 0.000038 seconds
#
#  9714: 0.303221, 0.207563 avg loss, 0.001000 rate, 10.180236 seconds, 621696 images
# Loaded: 0.000039 seconds
#
#  9715: 0.247746, 0.211582 avg loss, 0.001000 rate, 10.154811 seconds, 621760 images
# Loaded: 0.000059 seconds
#
#  9716: 0.203240, 0.210747 avg loss, 0.001000 rate, 10.157342 seconds, 621824 images
# Loaded: 0.000041 seconds
#
#  9717: 0.106630, 0.200336 avg loss, 0.001000 rate, 10.155282 seconds, 621888 images
# Loaded: 0.000047 seconds
#
#  9718: 0.203279, 0.200630 avg loss, 0.001000 rate, 10.163049 seconds, 621952 images
# Loaded: 0.000062 seconds
#
#  9719: 0.162398, 0.196807 avg loss, 0.001000 rate, 10.160645 seconds, 622016 images
# Loaded: 0.000045 seconds
#
#  9720: 0.183252, 0.195451 avg loss, 0.001000 rate, 10.177510 seconds, 622080 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 3.536134 seconds
#
#  9721: 0.266283, 0.202534 avg loss, 0.001000 rate, 15.177833 seconds, 622144 images
# Loaded: 0.000036 seconds
#
#  9722: 0.221579, 0.204439 avg loss, 0.001000 rate, 15.372000 seconds, 622208 images
# Loaded: 0.000048 seconds
#
#  9723: 0.224623, 0.206457 avg loss, 0.001000 rate, 15.329344 seconds, 622272 images
# Loaded: 0.000039 seconds
#
#  9724: 0.242020, 0.210014 avg loss, 0.001000 rate, 15.245253 seconds, 622336 images
# Loaded: 0.000063 seconds
#
#  9725: 0.246575, 0.213670 avg loss, 0.001000 rate, 15.194883 seconds, 622400 images
# Loaded: 0.000044 seconds
#
#  9726: 0.266945, 0.218997 avg loss, 0.001000 rate, 15.259109 seconds, 622464 images
# Loaded: 0.000063 seconds
#
#  9727: 0.214229, 0.218521 avg loss, 0.001000 rate, 15.288982 seconds, 622528 images
# Loaded: 0.000050 seconds
#
#  9728: 0.152999, 0.211968 avg loss, 0.001000 rate, 15.265746 seconds, 622592 images
# Loaded: 0.000064 seconds
#
#  9729: 0.136749, 0.204446 avg loss, 0.001000 rate, 15.265555 seconds, 622656 images
# Loaded: 0.000067 seconds
#
#  9730: 0.279938, 0.211996 avg loss, 0.001000 rate, 15.233398 seconds, 622720 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 2.073428 seconds
#
#  9731: 0.205620, 0.211358 avg loss, 0.001000 rate, 18.098288 seconds, 622784 images
# Loaded: 0.000040 seconds
#
#  9732: 0.252518, 0.215474 avg loss, 0.001000 rate, 18.280214 seconds, 622848 images
# Loaded: 0.000050 seconds
#
#  9733: 0.168468, 0.210773 avg loss, 0.001000 rate, 18.174611 seconds, 622912 images
# Loaded: 0.000040 seconds
#
#  9734: 0.261163, 0.215812 avg loss, 0.001000 rate, 18.178092 seconds, 622976 images
# Loaded: 0.000081 seconds
#
#  9735: 0.163764, 0.210607 avg loss, 0.001000 rate, 18.147018 seconds, 623040 images
# Loaded: 0.000038 seconds
#
#  9736: 0.180604, 0.207607 avg loss, 0.001000 rate, 18.214087 seconds, 623104 images
# Loaded: 0.000061 seconds
#
#  9737: 0.169572, 0.203804 avg loss, 0.001000 rate, 18.176533 seconds, 623168 images
# Loaded: 0.000057 seconds
#
#  9738: 0.337977, 0.217221 avg loss, 0.001000 rate, 18.183101 seconds, 623232 images
# Loaded: 0.000049 seconds
#
#  9739: 0.323777, 0.227877 avg loss, 0.001000 rate, 18.165355 seconds, 623296 images
# Loaded: 0.000030 seconds
#
#  9740: 0.185496, 0.223639 avg loss, 0.001000 rate, 18.174496 seconds, 623360 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.745964 seconds
#
#  9741: 0.230160, 0.224291 avg loss, 0.001000 rate, 7.568086 seconds, 623424 images
# Loaded: 0.000045 seconds
#
#  9742: 0.090374, 0.210899 avg loss, 0.001000 rate, 7.583448 seconds, 623488 images
# Loaded: 0.000043 seconds
#
#  9743: 0.267246, 0.216534 avg loss, 0.001000 rate, 7.580724 seconds, 623552 images
# Loaded: 0.000059 seconds
#
#  9744: 0.240139, 0.218894 avg loss, 0.001000 rate, 7.586451 seconds, 623616 images
# Loaded: 0.000044 seconds
#
#  9745: 0.277365, 0.224741 avg loss, 0.001000 rate, 7.557216 seconds, 623680 images
# Loaded: 0.000056 seconds
#
#  9746: 0.193663, 0.221634 avg loss, 0.001000 rate, 7.571965 seconds, 623744 images
# Loaded: 0.000043 seconds
#
#  9747: 0.246794, 0.224150 avg loss, 0.001000 rate, 7.544608 seconds, 623808 images
# Loaded: 0.000034 seconds
#
#  9748: 0.277709, 0.229505 avg loss, 0.001000 rate, 7.573227 seconds, 623872 images
# Loaded: 0.000038 seconds
#
#  9749: 0.202267, 0.226782 avg loss, 0.001000 rate, 7.536740 seconds, 623936 images
# Loaded: 0.000066 seconds
#
#  9750: 0.234473, 0.227551 avg loss, 0.001000 rate, 7.564585 seconds, 624000 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 2.874531 seconds
#
#  9751: 0.272499, 0.232046 avg loss, 0.001000 rate, 19.269040 seconds, 624064 images
# Loaded: 0.000039 seconds
#
#  9752: 0.247391, 0.233580 avg loss, 0.001000 rate, 19.557470 seconds, 624128 images
# Loaded: 0.000037 seconds
#
#  9753: 0.246724, 0.234895 avg loss, 0.001000 rate, 19.366029 seconds, 624192 images
# Loaded: 0.000035 seconds
#
#  9754: 0.252971, 0.236702 avg loss, 0.001000 rate, 19.343805 seconds, 624256 images
# Loaded: 0.000071 seconds
#
#  9755: 0.170863, 0.230118 avg loss, 0.001000 rate, 19.419124 seconds, 624320 images
# Loaded: 0.000047 seconds
#
#  9756: 0.169785, 0.224085 avg loss, 0.001000 rate, 19.447041 seconds, 624384 images
# Loaded: 0.000073 seconds
#
#  9757: 0.144098, 0.216086 avg loss, 0.001000 rate, 19.415060 seconds, 624448 images
# Loaded: 0.000039 seconds
#
#  9758: 0.247311, 0.219209 avg loss, 0.001000 rate, 19.455173 seconds, 624512 images
# Loaded: 0.000044 seconds
#
#  9759: 0.219806, 0.219268 avg loss, 0.001000 rate, 19.428294 seconds, 624576 images
# Loaded: 0.000042 seconds
#
#  9760: 0.193459, 0.216688 avg loss, 0.001000 rate, 19.387704 seconds, 624640 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 3.637865 seconds
#
#  9761: 0.224873, 0.217506 avg loss, 0.001000 rate, 7.046506 seconds, 624704 images
# Loaded: 0.000041 seconds
#
#  9762: 0.228107, 0.218566 avg loss, 0.001000 rate, 7.046979 seconds, 624768 images
# Loaded: 0.000041 seconds
#
#  9763: 0.237741, 0.220484 avg loss, 0.001000 rate, 7.066914 seconds, 624832 images
# Loaded: 0.000045 seconds
#
#  9764: 0.216607, 0.220096 avg loss, 0.001000 rate, 7.102052 seconds, 624896 images
# Loaded: 0.000056 seconds
#
#  9765: 0.191800, 0.217266 avg loss, 0.001000 rate, 7.108642 seconds, 624960 images
# Loaded: 0.000034 seconds
#
#  9766: 0.270251, 0.222565 avg loss, 0.001000 rate, 7.090332 seconds, 625024 images
# Loaded: 0.000062 seconds
#
#  9767: 0.186266, 0.218935 avg loss, 0.001000 rate, 7.076484 seconds, 625088 images
# Loaded: 0.000050 seconds
#
#  9768: 0.182504, 0.215292 avg loss, 0.001000 rate, 7.039000 seconds, 625152 images
# Loaded: 0.000046 seconds
#
#  9769: 0.168961, 0.210659 avg loss, 0.001000 rate, 7.023060 seconds, 625216 images
# Loaded: 0.000062 seconds
#
#  9770: 0.202021, 0.209795 avg loss, 0.001000 rate, 7.030595 seconds, 625280 images
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 1.458410 seconds
#
#  9771: 0.241206, 0.212936 avg loss, 0.001000 rate, 12.952732 seconds, 625344 images
# Loaded: 0.000036 seconds
#
#  9772: 0.289312, 0.220574 avg loss, 0.001000 rate, 13.048145 seconds, 625408 images
# Loaded: 0.000065 seconds
#
#  9773: 0.138156, 0.212332 avg loss, 0.001000 rate, 13.087127 seconds, 625472 images
# Loaded: 0.000079 seconds
#
#  9774: 0.159358, 0.207035 avg loss, 0.001000 rate, 13.024589 seconds, 625536 images
# Loaded: 0.000060 seconds
#
#  9775: 0.150011, 0.201332 avg loss, 0.001000 rate, 12.983071 seconds, 625600 images
# Loaded: 0.000044 seconds
#
#  9776: 0.219269, 0.203126 avg loss, 0.001000 rate, 12.988089 seconds, 625664 images
# Loaded: 0.000064 seconds
#
#  9777: 0.149276, 0.197741 avg loss, 0.001000 rate, 12.955449 seconds, 625728 images
# Loaded: 0.000052 seconds
#
#  9778: 0.172059, 0.195173 avg loss, 0.001000 rate, 12.987381 seconds, 625792 images
# Loaded: 0.000038 seconds
#
#  9779: 0.110328, 0.186688 avg loss, 0.001000 rate, 12.954880 seconds, 625856 images
# Loaded: 0.000035 seconds
#
#  9780: 0.209231, 0.188943 avg loss, 0.001000 rate, 12.980750 seconds, 625920 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 4.646099 seconds
#
#  9781: 0.279870, 0.198035 avg loss, 0.001000 rate, 7.551893 seconds, 625984 images
# Loaded: 0.000046 seconds
#
#  9782: 0.232612, 0.201493 avg loss, 0.001000 rate, 7.542776 seconds, 626048 images
# Loaded: 0.000073 seconds
#
#  9783: 0.156952, 0.197039 avg loss, 0.001000 rate, 7.598413 seconds, 626112 images
# Loaded: 0.000078 seconds
#
#  9784: 0.181199, 0.195455 avg loss, 0.001000 rate, 7.644098 seconds, 626176 images
# Loaded: 0.000047 seconds
#
#  9785: 0.143610, 0.190270 avg loss, 0.001000 rate, 7.623827 seconds, 626240 images
# Loaded: 0.000071 seconds
#
#  9786: 0.244765, 0.195720 avg loss, 0.001000 rate, 7.577704 seconds, 626304 images
# Loaded: 0.000034 seconds
#
#  9787: 0.216502, 0.197798 avg loss, 0.001000 rate, 7.569074 seconds, 626368 images
# Loaded: 0.000061 seconds
#
#  9788: 0.188773, 0.196896 avg loss, 0.001000 rate, 7.549857 seconds, 626432 images
# Loaded: 0.000059 seconds
#
#  9789: 0.124416, 0.189648 avg loss, 0.001000 rate, 7.536267 seconds, 626496 images
# Loaded: 0.000034 seconds
#
#  9790: 0.177932, 0.188476 avg loss, 0.001000 rate, 7.527212 seconds, 626560 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 3.673278 seconds
#
#  9791: 0.180069, 0.187635 avg loss, 0.001000 rate, 9.394472 seconds, 626624 images
# Loaded: 0.000044 seconds
#
#  9792: 0.114836, 0.180355 avg loss, 0.001000 rate, 9.474150 seconds, 626688 images
# Loaded: 0.000035 seconds
#
#  9793: 0.182721, 0.180592 avg loss, 0.001000 rate, 9.587870 seconds, 626752 images
# Loaded: 0.000060 seconds
#
#  9794: 0.216534, 0.184186 avg loss, 0.001000 rate, 9.552993 seconds, 626816 images
# Loaded: 0.000047 seconds
#
#  9795: 0.163545, 0.182122 avg loss, 0.001000 rate, 9.453922 seconds, 626880 images
# Loaded: 0.000033 seconds
#
#  9796: 0.296888, 0.193599 avg loss, 0.001000 rate, 9.426184 seconds, 626944 images
# Loaded: 0.000042 seconds
#
#  9797: 0.155844, 0.189823 avg loss, 0.001000 rate, 9.403658 seconds, 627008 images
# Loaded: 0.000064 seconds
#
#  9798: 0.147484, 0.185589 avg loss, 0.001000 rate, 9.409279 seconds, 627072 images
# Loaded: 0.000037 seconds
#
#  9799: 0.159842, 0.183014 avg loss, 0.001000 rate, 9.412560 seconds, 627136 images
# Loaded: 0.000040 seconds
#
#  9800: 0.178528, 0.182566 avg loss, 0.001000 rate, 9.440257 seconds, 627200 images
# Saving weights to /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_last.weights
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 2.939530 seconds
#
#  9801: 0.184642, 0.182773 avg loss, 0.001000 rate, 15.207090 seconds, 627264 images
# Loaded: 0.000067 seconds
#
#  9802: 0.265662, 0.191062 avg loss, 0.001000 rate, 15.476350 seconds, 627328 images
# Loaded: 0.000038 seconds
#
#  9803: 0.098461, 0.181802 avg loss, 0.001000 rate, 15.284642 seconds, 627392 images
# Loaded: 0.000042 seconds
#
#  9804: 0.202356, 0.183858 avg loss, 0.001000 rate, 15.192739 seconds, 627456 images
# Loaded: 0.000046 seconds
#
#  9805: 0.228212, 0.188293 avg loss, 0.001000 rate, 15.215478 seconds, 627520 images
# Loaded: 0.000067 seconds
#
#  9806: 0.235571, 0.193021 avg loss, 0.001000 rate, 15.250609 seconds, 627584 images
# Loaded: 0.000061 seconds
#
#  9807: 0.200523, 0.193771 avg loss, 0.001000 rate, 15.312259 seconds, 627648 images
# Loaded: 0.000041 seconds
#
#  9808: 0.216261, 0.196020 avg loss, 0.001000 rate, 15.286235 seconds, 627712 images
# Loaded: 0.000055 seconds
#
#  9809: 0.281532, 0.204571 avg loss, 0.001000 rate, 15.257833 seconds, 627776 images
# Loaded: 0.000045 seconds
#
#  9810: 0.168524, 0.200967 avg loss, 0.001000 rate, 15.239781 seconds, 627840 images
# Resizing
# 832 x 832
#  try to allocate additional workspace_size = 103.84 MB
#  CUDA allocate done!
# Loaded: 1.334459 seconds
#
#  9811: 0.249147, 0.205785 avg loss, 0.001000 rate, 19.289030 seconds, 627904 images
# Loaded: 0.000037 seconds
#
#  9812: 0.195325, 0.204739 avg loss, 0.001000 rate, 19.530690 seconds, 627968 images
# Loaded: 0.000039 seconds
#
#  9813: 0.186019, 0.202867 avg loss, 0.001000 rate, 19.362779 seconds, 628032 images
# Loaded: 0.000037 seconds
#
#  9814: 0.181562, 0.200736 avg loss, 0.001000 rate, 19.313348 seconds, 628096 images
# Loaded: 0.000064 seconds
#
#  9815: 0.176404, 0.198303 avg loss, 0.001000 rate, 19.403891 seconds, 628160 images
# Loaded: 0.000069 seconds
#
#  9816: 0.241529, 0.202626 avg loss, 0.001000 rate, 19.459125 seconds, 628224 images
# Loaded: 0.000038 seconds
#
#  9817: 0.279718, 0.210335 avg loss, 0.001000 rate, 19.433311 seconds, 628288 images
# Loaded: 0.000062 seconds
#
#  9818: 0.147832, 0.204085 avg loss, 0.001000 rate, 19.386579 seconds, 628352 images
# Loaded: 0.000036 seconds
#
#  9819: 0.216250, 0.205301 avg loss, 0.001000 rate, 19.362299 seconds, 628416 images
# Loaded: 0.000035 seconds
#
#  9820: 0.101411, 0.194912 avg loss, 0.001000 rate, 19.383662 seconds, 628480 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.701683 seconds
#
#  9821: 0.201412, 0.195562 avg loss, 0.001000 rate, 7.558198 seconds, 628544 images
# Loaded: 0.000057 seconds
#
#  9822: 0.192740, 0.195280 avg loss, 0.001000 rate, 7.562484 seconds, 628608 images
# Loaded: 0.000042 seconds
#
#  9823: 0.133611, 0.189113 avg loss, 0.001000 rate, 7.589015 seconds, 628672 images
# Loaded: 0.000039 seconds
#
#  9824: 0.136746, 0.183876 avg loss, 0.001000 rate, 7.600765 seconds, 628736 images
# Loaded: 0.000052 seconds
#
#  9825: 0.188467, 0.184335 avg loss, 0.001000 rate, 7.567813 seconds, 628800 images
# Loaded: 0.000037 seconds
#
#  9826: 0.207888, 0.186691 avg loss, 0.001000 rate, 7.579871 seconds, 628864 images
# Loaded: 0.000064 seconds
#
#  9827: 0.179654, 0.185987 avg loss, 0.001000 rate, 7.574283 seconds, 628928 images
# Loaded: 0.000080 seconds
#
#  9828: 0.322380, 0.199626 avg loss, 0.001000 rate, 7.573886 seconds, 628992 images
# Loaded: 0.000069 seconds
#
#  9829: 0.263079, 0.205972 avg loss, 0.001000 rate, 7.572370 seconds, 629056 images
# Loaded: 0.000050 seconds
#
#  9830: 0.200376, 0.205412 avg loss, 0.001000 rate, 7.568950 seconds, 629120 images
# Resizing
# 736 x 736
#  try to allocate additional workspace_size = 81.26 MB
#  CUDA allocate done!
# Loaded: 2.406973 seconds
#
#  9831: 0.283961, 0.213267 avg loss, 0.001000 rate, 15.137749 seconds, 629184 images
# Loaded: 0.000042 seconds
#
#  9832: 0.212254, 0.213166 avg loss, 0.001000 rate, 15.385482 seconds, 629248 images
# Loaded: 0.000047 seconds
#
#  9833: 0.160913, 0.207940 avg loss, 0.001000 rate, 15.332898 seconds, 629312 images
# Loaded: 0.000040 seconds
#
#  9834: 0.203907, 0.207537 avg loss, 0.001000 rate, 15.248919 seconds, 629376 images
# Loaded: 0.000046 seconds
#
#  9835: 0.226099, 0.209393 avg loss, 0.001000 rate, 15.193287 seconds, 629440 images
# Loaded: 0.000042 seconds
#
#  9836: 0.207687, 0.209223 avg loss, 0.001000 rate, 15.227825 seconds, 629504 images
# Loaded: 0.000035 seconds
#
#  9837: 0.247686, 0.213069 avg loss, 0.001000 rate, 15.286782 seconds, 629568 images
# Loaded: 0.000045 seconds
#
# ...
# Loaded: 0.000056 seconds
#
#  10776: 0.208060, 0.219487 avg loss, 0.001000 rate, 7.579938 seconds, 689664 images
# Loaded: 0.000033 seconds
#
#  10777: 0.243100, 0.221849 avg loss, 0.001000 rate, 7.553379 seconds, 689728 images
# Loaded: 0.000045 seconds
#
#  10778: 0.148689, 0.214533 avg loss, 0.001000 rate, 7.549787 seconds, 689792 images
# Loaded: 0.000043 seconds
#
#  10779: 0.256931, 0.218773 avg loss, 0.001000 rate, 7.590205 seconds, 689856 images
# Loaded: 0.000036 seconds
#
#  10780: 0.165654, 0.213461 avg loss, 0.001000 rate, 7.547082 seconds, 689920 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 0.871576 seconds
#
#  10781: 0.229653, 0.215080 avg loss, 0.001000 rate, 20.480474 seconds, 689984 images
# Loaded: 0.000033 seconds
#
#  10782: 0.180864, 0.211658 avg loss, 0.001000 rate, 20.712686 seconds, 690048 images
# Loaded: 0.000042 seconds
#
#  10783: 0.229535, 0.213446 avg loss, 0.001000 rate, 20.648465 seconds, 690112 images
# Loaded: 0.000055 seconds
#
#  10784: 0.148183, 0.206920 avg loss, 0.001000 rate, 20.658728 seconds, 690176 images
# Loaded: 0.000065 seconds
#
#  10785: 0.131597, 0.199387 avg loss, 0.001000 rate, 20.594591 seconds, 690240 images
# Loaded: 0.000051 seconds
#
#  10786: 0.203148, 0.199764 avg loss, 0.001000 rate, 20.626882 seconds, 690304 images
# Loaded: 0.000037 seconds
#
#  10787: 0.202000, 0.199987 avg loss, 0.001000 rate, 20.670306 seconds, 690368 images
# Loaded: 0.000041 seconds
#
#  10788: 0.250672, 0.205056 avg loss, 0.001000 rate, 20.648344 seconds, 690432 images
# Loaded: 0.000045 seconds
#
#  10789: 0.184639, 0.203014 avg loss, 0.001000 rate, 20.644098 seconds, 690496 images
# Loaded: 0.000037 seconds
#
#  10790: 0.114439, 0.194157 avg loss, 0.001000 rate, 20.636989 seconds, 690560 images
# Resizing
# 768 x 768
#  try to allocate additional workspace_size = 88.48 MB
#  CUDA allocate done!
# Loaded: 1.737257 seconds
#
#  10791: 0.275244, 0.202265 avg loss, 0.001000 rate, 16.184593 seconds, 690624 images
# Loaded: 0.000047 seconds
#
#  10792: 0.203206, 0.202359 avg loss, 0.001000 rate, 16.250191 seconds, 690688 images
# Loaded: 0.000049 seconds
#
#  10793: 0.117685, 0.193892 avg loss, 0.001000 rate, 16.279919 seconds, 690752 images
# Loaded: 0.000033 seconds
#
#  10794: 0.193218, 0.193824 avg loss, 0.001000 rate, 16.275759 seconds, 690816 images
# Loaded: 0.000070 seconds
#
#  10795: 0.240649, 0.198507 avg loss, 0.001000 rate, 16.243600 seconds, 690880 images
# Loaded: 0.000036 seconds
#
#  10796: 0.266269, 0.205283 avg loss, 0.001000 rate, 16.208070 seconds, 690944 images
# Loaded: 0.000053 seconds
#
#  10797: 0.145495, 0.199304 avg loss, 0.001000 rate, 16.192819 seconds, 691008 images
# Loaded: 0.000075 seconds
#
#  10798: 0.178310, 0.197205 avg loss, 0.001000 rate, 16.251897 seconds, 691072 images
# Loaded: 0.000046 seconds
#
#  10799: 0.225274, 0.200012 avg loss, 0.001000 rate, 16.260836 seconds, 691136 images
# Loaded: 0.000038 seconds
#
#  10800: 0.261182, 0.206129 avg loss, 0.001000 rate, 16.232090 seconds, 691200 images
# Saving weights to /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_last.weights
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.411405 seconds
#
#  10801: 0.260515, 0.211567 avg loss, 0.001000 rate, 7.054445 seconds, 691264 images
# Loaded: 0.000034 seconds
#
#  10802: 0.093530, 0.199764 avg loss, 0.001000 rate, 7.073279 seconds, 691328 images
# Loaded: 0.000041 seconds
#
#  10803: 0.236078, 0.203395 avg loss, 0.001000 rate, 7.072058 seconds, 691392 images
# Loaded: 0.000057 seconds
#
#  10804: 0.227698, 0.205825 avg loss, 0.001000 rate, 7.115849 seconds, 691456 images
# Loaded: 0.000048 seconds
#
#  10805: 0.177128, 0.202956 avg loss, 0.001000 rate, 7.109743 seconds, 691520 images
# Loaded: 0.000037 seconds
#
#  10806: 0.197685, 0.202429 avg loss, 0.001000 rate, 7.088147 seconds, 691584 images
# Loaded: 0.000036 seconds
#
#  10807: 0.218105, 0.203996 avg loss, 0.001000 rate, 7.108020 seconds, 691648 images
# Loaded: 0.000042 seconds
#
#  10808: 0.198461, 0.203443 avg loss, 0.001000 rate, 7.087592 seconds, 691712 images
# Loaded: 0.000037 seconds
#
#  10809: 0.224009, 0.205499 avg loss, 0.001000 rate, 7.039241 seconds, 691776 images
# Loaded: 0.000037 seconds
#
#  10810: 0.219415, 0.206891 avg loss, 0.001000 rate, 7.029944 seconds, 691840 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.142369 seconds
#
#  10811: 0.249996, 0.211201 avg loss, 0.001000 rate, 9.390300 seconds, 691904 images
# Loaded: 0.000038 seconds
#
#  10812: 0.126586, 0.202740 avg loss, 0.001000 rate, 9.439128 seconds, 691968 images
# Loaded: 0.000051 seconds
#
#  10813: 0.192349, 0.201701 avg loss, 0.001000 rate, 9.440337 seconds, 692032 images
# Loaded: 0.000036 seconds
#
#  10814: 0.141116, 0.195642 avg loss, 0.001000 rate, 9.471456 seconds, 692096 images
# Loaded: 0.000042 seconds
#
#  10815: 0.221255, 0.198204 avg loss, 0.001000 rate, 9.461663 seconds, 692160 images
# Loaded: 0.000042 seconds
#
#  10816: 0.143819, 0.192765 avg loss, 0.001000 rate, 9.463433 seconds, 692224 images
# Loaded: 0.000032 seconds
#
#  10817: 0.129561, 0.186445 avg loss, 0.001000 rate, 9.466624 seconds, 692288 images
# Loaded: 0.000038 seconds
#
#  10818: 0.190445, 0.186845 avg loss, 0.001000 rate, 9.441495 seconds, 692352 images
# Loaded: 0.000064 seconds
#
#  10819: 0.229944, 0.191155 avg loss, 0.001000 rate, 9.454786 seconds, 692416 images
# Loaded: 0.000070 seconds
#
#  10820: 0.300766, 0.202116 avg loss, 0.001000 rate, 9.445722 seconds, 692480 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.649691 seconds
#
#  10821: 0.203519, 0.202256 avg loss, 0.001000 rate, 9.364227 seconds, 692544 images
# Loaded: 0.000054 seconds
#
#  10822: 0.122165, 0.194247 avg loss, 0.001000 rate, 9.450899 seconds, 692608 images
# Loaded: 0.000044 seconds
#
#  10823: 0.160423, 0.190865 avg loss, 0.001000 rate, 9.464627 seconds, 692672 images
# Loaded: 0.000037 seconds
#
#  10824: 0.123549, 0.184133 avg loss, 0.001000 rate, 9.454442 seconds, 692736 images
# Loaded: 0.000062 seconds
#
#  10825: 0.160997, 0.181819 avg loss, 0.001000 rate, 9.461108 seconds, 692800 images
# Loaded: 0.000030 seconds
#
#  10826: 0.214096, 0.185047 avg loss, 0.001000 rate, 9.453767 seconds, 692864 images
# Loaded: 0.000061 seconds
#
#  10827: 0.162400, 0.182782 avg loss, 0.001000 rate, 9.444469 seconds, 692928 images
# Loaded: 0.000065 seconds
#
#  10828: 0.171155, 0.181620 avg loss, 0.001000 rate, 9.447506 seconds, 692992 images
# Loaded: 0.000031 seconds
#
#  10829: 0.152961, 0.178754 avg loss, 0.001000 rate, 9.435155 seconds, 693056 images
# Loaded: 0.000040 seconds
#
#  10830: 0.147708, 0.175649 avg loss, 0.001000 rate, 9.452749 seconds, 693120 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.586173 seconds
#
#  10831: 0.213443, 0.179429 avg loss, 0.001000 rate, 7.488187 seconds, 693184 images
# Loaded: 0.000050 seconds
#
#  10832: 0.159934, 0.177479 avg loss, 0.001000 rate, 7.575463 seconds, 693248 images
# Loaded: 0.000042 seconds
#
#  10833: 0.188286, 0.178560 avg loss, 0.001000 rate, 7.579532 seconds, 693312 images
# Loaded: 0.000062 seconds
#
#  10834: 0.192022, 0.179906 avg loss, 0.001000 rate, 7.572246 seconds, 693376 images
# Loaded: 0.000045 seconds
#
#  10835: 0.179141, 0.179830 avg loss, 0.001000 rate, 7.575662 seconds, 693440 images
# Loaded: 0.000064 seconds
#
#  10836: 0.200380, 0.181885 avg loss, 0.001000 rate, 7.572142 seconds, 693504 images
# Loaded: 0.000032 seconds
#
#  10837: 0.113775, 0.175074 avg loss, 0.001000 rate, 7.556714 seconds, 693568 images
# Loaded: 0.000061 seconds
#
#  10838: 0.251117, 0.182678 avg loss, 0.001000 rate, 7.566627 seconds, 693632 images
# Loaded: 0.000034 seconds
#
#  10839: 0.226491, 0.187059 avg loss, 0.001000 rate, 7.584146 seconds, 693696 images
# Loaded: 0.000033 seconds
#
#  10840: 0.258524, 0.194206 avg loss, 0.001000 rate, 7.559749 seconds, 693760 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 74.35 MB
#  CUDA allocate done!
# Loaded: 0.914800 seconds
#
#  10841: 0.181895, 0.192975 avg loss, 0.001000 rate, 13.838248 seconds, 693824 images
# Loaded: 0.000065 seconds
#
#  10842: 0.097524, 0.183430 avg loss, 0.001000 rate, 13.917260 seconds, 693888 images
# Loaded: 0.000057 seconds
#
#  10843: 0.270279, 0.192115 avg loss, 0.001000 rate, 13.942093 seconds, 693952 images
# Loaded: 0.000041 seconds
#
#  10844: 0.143133, 0.187217 avg loss, 0.001000 rate, 13.937309 seconds, 694016 images
# Loaded: 0.000045 seconds
#
#  10845: 0.178327, 0.186328 avg loss, 0.001000 rate, 13.891144 seconds, 694080 images
# Loaded: 0.000035 seconds
#
#  10846: 0.148995, 0.182594 avg loss, 0.001000 rate, 13.914024 seconds, 694144 images
# Loaded: 0.000035 seconds
#
#  10847: 0.236479, 0.187983 avg loss, 0.001000 rate, 13.891222 seconds, 694208 images
# Loaded: 0.000056 seconds
#
#  10848: 0.152855, 0.184470 avg loss, 0.001000 rate, 13.904523 seconds, 694272 images
# Loaded: 0.000065 seconds
#
#  10849: 0.207339, 0.186757 avg loss, 0.001000 rate, 13.918321 seconds, 694336 images
# Loaded: 0.000060 seconds
#
#  10850: 0.134271, 0.181508 avg loss, 0.001000 rate, 13.919472 seconds, 694400 images
# Resizing
# 672 x 672
#  try to allocate additional workspace_size = 67.74 MB
#  CUDA allocate done!
# Loaded: 1.714164 seconds
#
#  10851: 0.133498, 0.176707 avg loss, 0.001000 rate, 12.913405 seconds, 694464 images
# Loaded: 0.000071 seconds
#
#  10852: 0.170445, 0.176081 avg loss, 0.001000 rate, 13.002417 seconds, 694528 images
# Loaded: 0.000055 seconds
#
#  10853: 0.190858, 0.177559 avg loss, 0.001000 rate, 12.994410 seconds, 694592 images
# Loaded: 0.000043 seconds
#
#  10854: 0.064001, 0.166203 avg loss, 0.001000 rate, 13.011187 seconds, 694656 images
# Loaded: 0.000041 seconds
#
#  10855: 0.188076, 0.168390 avg loss, 0.001000 rate, 12.978833 seconds, 694720 images
# Loaded: 0.000054 seconds
#
#  10856: 0.236491, 0.175200 avg loss, 0.001000 rate, 13.004643 seconds, 694784 images
# Loaded: 0.000056 seconds
#
#  10857: 0.173660, 0.175046 avg loss, 0.001000 rate, 12.975565 seconds, 694848 images
# Loaded: 0.000055 seconds
#
#  10858: 0.218686, 0.179410 avg loss, 0.001000 rate, 13.005977 seconds, 694912 images
# Loaded: 0.000045 seconds
#
#  10859: 0.154608, 0.176930 avg loss, 0.001000 rate, 12.983265 seconds, 694976 images
# Loaded: 0.000067 seconds
#
#  10860: 0.219020, 0.181139 avg loss, 0.001000 rate, 12.987397 seconds, 695040 images
# Resizing
# 704 x 704
#  try to allocate additional workspace_size = 74.35 MB
#  CUDA allocate done!
# Loaded: 1.287466 seconds
#
#  10861: 0.143681, 0.177393 avg loss, 0.001000 rate, 13.871358 seconds, 695104 images
# Loaded: 0.000045 seconds
#
#  10862: 0.129642, 0.172618 avg loss, 0.001000 rate, 13.919661 seconds, 695168 images
# Loaded: 0.000054 seconds
#
#  10863: 0.229773, 0.178334 avg loss, 0.001000 rate, 13.940394 seconds, 695232 images
# Loaded: 0.000040 seconds
#
#  10864: 0.122841, 0.172784 avg loss, 0.001000 rate, 13.906657 seconds, 695296 images
# Loaded: 0.000043 seconds
#
#  10865: 0.181473, 0.173653 avg loss, 0.001000 rate, 13.912094 seconds, 695360 images
# Loaded: 0.000055 seconds
#
#  10866: 0.276860, 0.183974 avg loss, 0.001000 rate, 13.946972 seconds, 695424 images
# Loaded: 0.000049 seconds
#
#  10867: 0.169463, 0.182523 avg loss, 0.001000 rate, 13.916554 seconds, 695488 images
# Loaded: 0.000035 seconds
#
#  10868: 0.121528, 0.176423 avg loss, 0.001000 rate, 13.901262 seconds, 695552 images
# Loaded: 0.000059 seconds
#
#  10869: 0.201962, 0.178977 avg loss, 0.001000 rate, 13.901078 seconds, 695616 images
# Loaded: 0.000045 seconds
#
#  10870: 0.179644, 0.179044 avg loss, 0.001000 rate, 13.922416 seconds, 695680 images
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 0.580703 seconds
#
#  10871: 0.215162, 0.182656 avg loss, 0.001000 rate, 20.499638 seconds, 695744 images
# Loaded: 0.000040 seconds
#
#  10872: 0.201565, 0.184547 avg loss, 0.001000 rate, 20.705050 seconds, 695808 images
# Loaded: 0.000037 seconds
#
#  10873: 0.257983, 0.191890 avg loss, 0.001000 rate, 20.656212 seconds, 695872 images
# Loaded: 0.000041 seconds
#
#  10874: 0.218663, 0.194568 avg loss, 0.001000 rate, 20.629471 seconds, 695936 images
# Loaded: 0.000050 seconds
#
#  10875: 0.149701, 0.190081 avg loss, 0.001000 rate, 20.605399 seconds, 696000 images
# Loaded: 0.000043 seconds
#
#  10876: 0.142099, 0.185283 avg loss, 0.001000 rate, 20.636651 seconds, 696064 images
# Loaded: 0.000066 seconds
#
#  10877: 0.168447, 0.183599 avg loss, 0.001000 rate, 20.687594 seconds, 696128 images
# Loaded: 0.000038 seconds
#
#  10878: 0.173197, 0.182559 avg loss, 0.001000 rate, 20.647649 seconds, 696192 images
# Loaded: 0.000040 seconds
#
#  10879: 0.249723, 0.189275 avg loss, 0.001000 rate, 20.676334 seconds, 696256 images
# Loaded: 0.000034 seconds
#
#  10880: 0.192510, 0.189599 avg loss, 0.001000 rate, 20.665548 seconds, 696320 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 1.153328 seconds
#
#  10881: 0.231837, 0.193823 avg loss, 0.001000 rate, 6.987635 seconds, 696384 images
# Loaded: 0.000045 seconds
#
#  10882: 0.173711, 0.191812 avg loss, 0.001000 rate, 7.050222 seconds, 696448 images
# Loaded: 0.000045 seconds
#
#  10883: 0.212130, 0.193843 avg loss, 0.001000 rate, 7.070397 seconds, 696512 images
# Loaded: 0.000039 seconds
#
#  10884: 0.090230, 0.183482 avg loss, 0.001000 rate, 7.051203 seconds, 696576 images
# Loaded: 0.000048 seconds
#
#  10885: 0.166244, 0.181758 avg loss, 0.001000 rate, 7.047069 seconds, 696640 images
# Loaded: 0.000042 seconds
#
#  10886: 0.212856, 0.184868 avg loss, 0.001000 rate, 7.058768 seconds, 696704 images
# Loaded: 0.000047 seconds
#
#  10887: 0.156981, 0.182079 avg loss, 0.001000 rate, 7.036925 seconds, 696768 images
# Loaded: 0.000041 seconds
#
#  10888: 0.161656, 0.180037 avg loss, 0.001000 rate, 7.075742 seconds, 696832 images
# Loaded: 0.000037 seconds
#
#  10889: 0.192442, 0.181277 avg loss, 0.001000 rate, 7.074059 seconds, 696896 images
# Loaded: 0.000051 seconds
#
#  10890: 0.171043, 0.180254 avg loss, 0.001000 rate, 7.054538 seconds, 696960 images
# Resizing
# 800 x 800
#  try to allocate additional workspace_size = 96.00 MB
#  CUDA allocate done!
# Loaded: 0.898430 seconds
#
#  10891: 0.241033, 0.186332 avg loss, 0.001000 rate, 18.065780 seconds, 697024 images
# Loaded: 0.000038 seconds
#
#  10892: 0.147259, 0.182425 avg loss, 0.001000 rate, 18.196421 seconds, 697088 images
# Loaded: 0.000047 seconds
#
#  10893: 0.252274, 0.189410 avg loss, 0.001000 rate, 18.162940 seconds, 697152 images
# Loaded: 0.000041 seconds
#
#  10894: 0.176142, 0.188083 avg loss, 0.001000 rate, 18.149987 seconds, 697216 images
# Loaded: 0.000058 seconds
#
#  10895: 0.240153, 0.193290 avg loss, 0.001000 rate, 18.188741 seconds, 697280 images
# Loaded: 0.000052 seconds
#
#  10896: 0.313683, 0.205329 avg loss, 0.001000 rate, 18.181072 seconds, 697344 images
# Loaded: 0.000036 seconds
#
#  10897: 0.178734, 0.202670 avg loss, 0.001000 rate, 18.167722 seconds, 697408 images
# Loaded: 0.000074 seconds
#
#  10898: 0.197974, 0.202200 avg loss, 0.001000 rate, 18.195849 seconds, 697472 images
# Loaded: 0.000049 seconds
#
#  10899: 0.119986, 0.193979 avg loss, 0.001000 rate, 18.166164 seconds, 697536 images
# Loaded: 0.000036 seconds
#
#  10900: 0.377718, 0.212353 avg loss, 0.001000 rate, 18.174677 seconds, 697600 images
# Saving weights to /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_last.weights
# Resizing
# 864 x 864
#  try to allocate additional workspace_size = 111.98 MB
#  CUDA allocate done!
# Loaded: 0.249240 seconds
#
#  10901: 0.254313, 0.216549 avg loss, 0.001000 rate, 20.513692 seconds, 697664 images
# Loaded: 0.000033 seconds
#
#  10902: 0.174507, 0.212345 avg loss, 0.001000 rate, 20.716919 seconds, 697728 images
# Loaded: 0.000050 seconds
#
#  10903: 0.213179, 0.212428 avg loss, 0.001000 rate, 20.640041 seconds, 697792 images
# Loaded: 0.000037 seconds
#
#  10904: 0.259143, 0.217099 avg loss, 0.001000 rate, 20.637808 seconds, 697856 images
# Loaded: 0.000035 seconds
#
#  10905: 0.206590, 0.216048 avg loss, 0.001000 rate, 20.642479 seconds, 697920 images
# Loaded: 0.000034 seconds
#
#  10906: 0.254947, 0.219938 avg loss, 0.001000 rate, 20.669949 seconds, 697984 images
# Loaded: 0.000061 seconds

# %%
# !./darknet detector map '$objdata' '$yolov3cfg' '$last_weights' -thresh 0.15
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32 0.639 BF
#    1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64 3.407 BF
#    2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32 0.379 BF
#    3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128 3.407 BF
#    6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#    7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#   10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   152 x 152 x 128   ->    76 x  76 x 256 3.407 BF
#   13 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   14 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   17 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   20 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   23 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   26 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   29 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   32 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   35 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    76 x  76 x 256   ->    38 x  38 x 512 3.407 BF
#   38 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   39 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   42 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   45 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   48 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   51 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   54 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   57 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   60 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    38 x  38 x 512   ->    19 x  19 x1024 3.407 BF
#   63 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   64 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   67 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   70 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   73 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   76 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   77 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   78 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   79 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   80 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   81 conv     18  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x  18 0.013 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    19 x  19 x 512   ->    19 x  19 x 256 0.095 BF
#   85 upsample            2x    19 x  19 x 256   ->    38 x  38 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    38 x  38 x 768   ->    38 x  38 x 256 0.568 BF
#   88 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   89 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   90 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   91 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   92 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   93 conv     18  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x  18 0.027 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    38 x  38 x 256   ->    38 x  38 x 128 0.095 BF
#   97 upsample            2x    38 x  38 x 128   ->    76 x  76 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    76 x  76 x 384   ->    76 x  76 x 128 0.568 BF
#  100 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  101 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  102 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  103 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  104 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  105 conv     18  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x  18 0.053 BF
#  106 yolo
# Total BFLOPS 139.465
#  Allocate additional workspace_size = 55.45 MB
# Loading weights from /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup/yolo-obj1_last.weights...
#  seen 64
# Done!
#
#  calculation mAP (mean average precision)...
# 4004
#  detections_count = 9917, unique_truth_count = 1435
# class_id = 0, name = Lung Opacity, ap = 16.55%   	 (TP = 0, FP = 0)
#
#  for thresh = 0.35, precision = -nan, recall = 0.00, F1-score = -nan
#  for thresh = 0.35, TP = 0, FP = 0, FN = 1435, average IoU = 0.00 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.165539, or 16.55 %
# Total Detection Time: 226.000000 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map '$objdata' '$yolov3cfg' '$weights11k' -thresh 0.2
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32 0.639 BF
#    1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64 3.407 BF
#    2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32 0.379 BF
#    3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128 3.407 BF
#    6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#    7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#   10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   152 x 152 x 128   ->    76 x  76 x 256 3.407 BF
#   13 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   14 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   17 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   20 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   23 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   26 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   29 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   32 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   35 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    76 x  76 x 256   ->    38 x  38 x 512 3.407 BF
#   38 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   39 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   42 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   45 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   48 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   51 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   54 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   57 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   60 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    38 x  38 x 512   ->    19 x  19 x1024 3.407 BF
#   63 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   64 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   67 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   70 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   73 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   76 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   77 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   78 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   79 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   80 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   81 conv     18  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x  18 0.013 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    19 x  19 x 512   ->    19 x  19 x 256 0.095 BF
#   85 upsample            2x    19 x  19 x 256   ->    38 x  38 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    38 x  38 x 768   ->    38 x  38 x 256 0.568 BF
#   88 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   89 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   90 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   91 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   92 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   93 conv     18  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x  18 0.027 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    38 x  38 x 256   ->    38 x  38 x 128 0.095 BF
#   97 upsample            2x    38 x  38 x 128   ->    76 x  76 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    76 x  76 x 384   ->    76 x  76 x 128 0.568 BF
#  100 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  101 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  102 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  103 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  104 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  105 conv     18  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x  18 0.053 BF
#  106 yolo
# Total BFLOPS 139.465
#  Allocate additional workspace_size = 6.65 MB
# Loading weights from /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_12000.weights...
#  seen 64
# Done!
#
#  calculation mAP (mean average precision)...
# 4Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/3bb9dce3-3f58-4a41-a75c-fa0748eb288b.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/ae34e246-4d09-4cd1-89c9-b3107a1553dc.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/62d2cb35-a998-4a35-992c-8ab5fa03958f.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/68fce9ea-3122-49bd-8968-85e8f9315c83.jpg
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/3bb9dce3-3f58-4a41-a75c-fa0748eb288b.txt
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/fcabeae4-2631-494c-b7f9-f96d6da5e0ab.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/760fc611-b3ee-4504-876d-ff864b3b3f88.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/6f5756a4-71c9-4c21-9107-b6163537b213.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/bd59abda-3e57-4be0-9140-22c8f6de8c3c.jpg
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/62d2cb35-a998-4a35-992c-8ab5fa03958f.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/68fce9ea-3122-49bd-8968-85e8f9315c83.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/ae34e246-4d09-4cd1-89c9-b3107a1553dc.txt
# 12Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/8b3dccfa-0ea1-4503-9c12-47bb4008b271.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/cbe2cae7-00e2-4255-bc97-84a9a5059ec5.jpg
# 4004
#  detections_count = 3869, unique_truth_count = 1433
# class_id = 0, name = Lung Opacity, ap = 16.73%   	 (TP = 7, FP = 6)
#
#  for thresh = 0.20, precision = 0.54, recall = 0.00, F1-score = 0.01
#  for thresh = 0.20, TP = 7, FP = 6, FN = 1426, average IoU = 40.41 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.167315, or 16.73 %
# Total Detection Time: 2172.000000 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map '$objdata' '$yolov3cfg' '$weights12k' -thresh 0.15
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32 0.639 BF
#    1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64 3.407 BF
#    2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32 0.379 BF
#    3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128 3.407 BF
#    6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#    7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#   10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   152 x 152 x 128   ->    76 x  76 x 256 3.407 BF
#   13 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   14 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   17 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   20 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   23 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   26 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   29 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   32 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   35 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    76 x  76 x 256   ->    38 x  38 x 512 3.407 BF
#   38 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   39 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   42 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   45 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   48 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   51 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   54 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   57 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   60 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    38 x  38 x 512   ->    19 x  19 x1024 3.407 BF
#   63 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   64 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   67 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   70 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   73 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   76 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   77 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   78 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   79 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   80 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   81 conv     18  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x  18 0.013 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    19 x  19 x 512   ->    19 x  19 x 256 0.095 BF
#   85 upsample            2x    19 x  19 x 256   ->    38 x  38 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    38 x  38 x 768   ->    38 x  38 x 256 0.568 BF
#   88 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   89 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   90 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   91 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   92 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   93 conv     18  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x  18 0.027 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    38 x  38 x 256   ->    38 x  38 x 128 0.095 BF
#   97 upsample            2x    38 x  38 x 128   ->    76 x  76 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    76 x  76 x 384   ->    76 x  76 x 128 0.568 BF
#  100 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  101 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  102 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  103 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  104 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  105 conv     18  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x  18 0.053 BF
#  106 yolo
# Total BFLOPS 139.465
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_12000.weights...
#  seen 64
# Done!
#
#  calculation mAP (mean average precision)...
# 4Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/3bb9dce3-3f58-4a41-a75c-fa0748eb288b.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/62d2cb35-a998-4a35-992c-8ab5fa03958f.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/68fce9ea-3122-49bd-8968-85e8f9315c83.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/ae34e246-4d09-4cd1-89c9-b3107a1553dc.jpg
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/3bb9dce3-3f58-4a41-a75c-fa0748eb288b.txt
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/bd59abda-3e57-4be0-9140-22c8f6de8c3c.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/fcabeae4-2631-494c-b7f9-f96d6da5e0ab.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/760fc611-b3ee-4504-876d-ff864b3b3f88.jpg
# Cannot load image /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/6f5756a4-71c9-4c21-9107-b6163537b213.jpg
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/62d2cb35-a998-4a35-992c-8ab5fa03958f.txt
# Can't open label file. (This can be normal only if you use MSCOCO): /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/68fce9ea-3122-49bd-8968-85e8f9315c83.txt
# 4004
#  detections_count = 3871, unique_truth_count = 1433
# class_id = 0, name = Lung Opacity, ap = 16.73%   	 (TP = 31, FP = 16)
#
#  for thresh = 0.15, precision = 0.66, recall = 0.02, F1-score = 0.04
#  for thresh = 0.15, TP = 31, FP = 16, FN = 1402, average IoU = 46.02 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.167313, or 16.73 %
# Total Detection Time: 1635.000000 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map '$objdata' '$yolov3cfg' '$weights2k' -thresh 0.15
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32 0.639 BF
#    1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64 3.407 BF
#    2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32 0.379 BF
#    3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128 3.407 BF
#    6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#    7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64 0.379 BF
#   10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   152 x 152 x 128   ->    76 x  76 x 256 3.407 BF
#   13 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   14 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   17 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   20 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   23 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   26 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   29 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   32 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#   35 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    76 x  76 x 256   ->    38 x  38 x 512 3.407 BF
#   38 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   39 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   42 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   45 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   48 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   51 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   54 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   57 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   60 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    38 x  38 x 512   ->    19 x  19 x1024 3.407 BF
#   63 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   64 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   67 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   70 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   73 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   76 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   77 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   78 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   79 conv    512  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x 512 0.379 BF
#   80 conv   1024  3 x 3 / 1    19 x  19 x 512   ->    19 x  19 x1024 3.407 BF
#   81 conv     18  1 x 1 / 1    19 x  19 x1024   ->    19 x  19 x  18 0.013 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    19 x  19 x 512   ->    19 x  19 x 256 0.095 BF
#   85 upsample            2x    19 x  19 x 256   ->    38 x  38 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    38 x  38 x 768   ->    38 x  38 x 256 0.568 BF
#   88 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   89 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   90 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   91 conv    256  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x 256 0.379 BF
#   92 conv    512  3 x 3 / 1    38 x  38 x 256   ->    38 x  38 x 512 3.407 BF
#   93 conv     18  1 x 1 / 1    38 x  38 x 512   ->    38 x  38 x  18 0.027 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    38 x  38 x 256   ->    38 x  38 x 128 0.095 BF
#   97 upsample            2x    38 x  38 x 128   ->    76 x  76 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    76 x  76 x 384   ->    76 x  76 x 128 0.568 BF
#  100 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  101 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  102 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  103 conv    128  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x 128 0.379 BF
#  104 conv    256  3 x 3 / 1    76 x  76 x 128   ->    76 x  76 x 256 3.407 BF
#  105 conv     18  1 x 1 / 1    76 x  76 x 256   ->    76 x  76 x  18 0.053 BF
#  106 yolo
# Total BFLOPS 139.465
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/backup//yolo-obj1_2000.weights...
#  seen 64
# Done!
#
#  calculation mAP (mean average precision)...
# 4004
#  detections_count = 27550, unique_truth_count = 1435
# class_id = 0, name = Lung Opacity, ap = 11.37%   	 (TP = 214, FP = 553)
#
#  for thresh = 0.15, precision = 0.28, recall = 0.15, F1-score = 0.19
#  for thresh = 0.15, TP = 214, FP = 553, FN = 1221, average IoU = 17.37 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.113653, or 11.37 %
# Total Detection Time: 167.000000 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %% [markdown]
# ## Performance analysis

# %% [markdown]
# ### mAP and IoU
#
# Se utilizó el comando presentado anteriormente para evaluar el modelo (con el subset de validation) con los pesos correspondientes al número de iteraciones. A continuación, se presentan las métricas obtenidas indicado a qué instancia de entrenamiento corresponden. El primer número *detections_count* es el número de detecciones en las 4004 imágenes de validation. Cabe aclarar que puede haber más de una detección por imagen. El segundo número *unique_truth_count* corresponde al número de opacidades que *efectivamente había* en el subset de validation. El *class_id* es siempre 0 ya que la única clase de objetos detectados es "Lung Opacity". El valor *ap* corresponde a la precisión promedio y se vuelve a indicar como el *mAP* (mean average precision), calculado con un umbral de 0,5. Las siglas *TP* y *FP* corresponden a verdaderos y falsos positivos respectivamente, mientras que *FN* son los falsos negativos.
#
# Por default, Darknet descarta las detecciones cuya confidence se encuentre por debajo de 0,25. Este umbral es un hiperparámetro seteable. El *average IoU* indicado se calcula con los verdaderos positivos por lo que de ser nulos, este indicador será siempre nulo. Con el afán de mejor las métricas obtenidas, se estudió el efecto de la modificación del umbral de confidence mencionado. El *mAP* no resultó sensible a estas modificaciones, mientras que el IoU sí. La justificación para este fenómeno se explica en la sección de discusión.
#
# El hecho de que el mAP en validation comience a bajar a partir de las 9000 iteraciones mientras que el average loss disminuía indica que a partir de entonces, el modelo comenzaba a presentar overfitting.
#
# A continuación se presenta la condensación de los resultados obtenidos:
#
# Interaciones | mAP | threshold | Average IoU
# ------------- | ------------- | ------------- | -------------
# 16000 | 0,119088 | 0,25 | 0,2998
# 15000 | 0,122389 | 0,20 | 0,3327
# 14000 | 0,141642 | 0,20 | 0,3161
# 13000 | 0,118111 | 0,20 | 0
# 12000 | 0,168019 | 0,25 | 0
# 12000 | 0,168411 | 0,2 | 0.4041
# 12000 | 0,168411 | 0,15 | 0,4640
# 11000 | 0,168019 | 0,15 | 0,4917
# 11000 | 0,135366 | 0,15 | 0,3976

# %% [markdown]
# ##Matriz de confusión
#
# Presentamos como ejemplo dos matrices de confusión, la de 12000 iteraciones, con un threshold de 0.2:
#
# - Especificidad: 0.5384
# - Sensibilidad: 0.6427
#
#
#
#  modelo/anotaciones | Verdaderos Positivos | Verdadero Negativo
# ------------- | ------------- | -------------
# Positivo | 7 | 6
# Negativo | 1426 | 2565

# %% [markdown]
# con un threshold de 0.15:
#
# - Especificidad : 0.6595
# - Sensibilidad: 0.5457
#
#
#  modelo/realidad | Verdaderos Positivos | Verdadero Negativo
# ------------- | ------------- | -------------
# Positivo | 31 | 16
# Negativo | 1402 | 2555

# %% [markdown]
# # Test
# Como la competencia de RSNA en la plataforma de Kaggle sigue estando activa aunque haya terminado, aún se pueden realizar submissions y obtener el score correspondiente. Por esto, desde un inicio se optó por utilizar esta herramienta para testear nuestro modelo y se dividió el subset de train disponible únicamente en train y validation, proyectando generar un archivo .csv para subir a dicha competencia al llegar a la instancia de test.

# %%
test_jpg_dir = '/content/drive/My Drive/Final_redes/test_images/stage_2_test_images_jpg'
test_txt_dir = '/content/drive/My Drive/Final_redes/Notebooks/DarkNet-flipped/test.txt'

# %% [markdown]
# ## Predicción del subset de test
# Se realizó una predicción en bloque: con este comando, se corre el comando de test para cada una de las imágenes (una línea por imagen en el archivo test.txt cuya dirección se indica en la celda anterior) y se acumulan en el archivo de salida rsna_result#.txt

# %%
# !./darknet detector test '$objdata' '$yolov3cfg' '$weights9k' -thresh 0.15 -width 1024 -height 1024 -dont_show < '$test_txt_dir' > rsna_result3.txt

# %% [markdown]
# ## Armado del archivo para la submission en Kaggle
# Para esto, se utilizó el trabajo de un estudiante de Bengaluru, Karnataka, India, publicado bajo el seudónimo anil777 [3]. Desarrolló un conjunto de funciones disponibles en el archivo parse_darknet_output.py que pueden utilizarse para convertir un archivo .txt con la salida de un testeo de Darknet en un archivo .csv listo para submittearse en Kaggle como predicciones. Fue necesario que le realicemos ligeras modificaciones pero a grandes rasgos, las funciones son propiedad de él.

# %%
# !python parse_darknet_output.py -i 'rsna_result3.txt' -o 'submission256_3.csv'

# %% [markdown]
# Para estudiar lo obtenido, se importó el .csv de salida como un pandas dataframe.

# %%
submission256_3 = pd.read_csv('submission256_3.csv')

# %% [markdown]
# Este comando permite concluir que se detectaron opacidades pulmonares en 300 imágenes de test, ya que filtra el resultado para mostrar únicamente los registros con un prediction string no nulo.

# %%
submission256_3[submission256_3['PredictionString'].notnull()]

# %% [markdown]
# El prediction string está compuesto de la confidence de la detección y las coordenadas de la bounding box (x1 e y1 son las coordenadas de la esquina superior izquierda y width y height son el ancho y alto de la bounding box, todos expresados en número de píxeles):
#
# < confidence > < x1 > < y1 > < width > < height >
#
# En nuestro caso, estas coordenadas se imprimen siempre con el mismo número de posiciones. Esto hace que se impriman como números con espacios que los separan por demás. Hay que procesar la salida obtenida para prepararla para la submission, eliminando estos espacios.

# %%
new_preds = [' '.join([str(float(s)) for s in p.split(' ') if len(s)>0])  if isinstance(p,str) else np.NaN for p in submission256_3['PredictionString']] 
df_submission_processed = submission256_3.copy()
df_submission_processed['PredictionString'] = new_preds

# %% [markdown]
# Por último se guarda el csv resultante. Sin embargo, nunca conseguimos obtener un score distinto de 0 al publicar en Kaggle. Luego de confirmar que estábamos armando los prediction strings de forma adecuada, nuestra primer conclusión era que esto se debía a un problema de escala.

# %%
df_submission_processed.to_csv('submission_256_3_processed.csv',index=False)

# %% [markdown]
# # Exploración de resultados

# %% [markdown]
# Al estudiar la submission obtenida como se detalló, no se obtuvieron los resultados esperados. Originalmente, se observó que los bounding boxes parecían ***fuera de escala***.
#
# Se arribó a esta conclusión debido a que en todos los casos donde la red detecta opacidades pulmonares, éstas se encuentran siempre en la esquina superior izquierda de la imagen y tienen un área ligeramente inferior. En caso de ser más de una, se observa que su posición se asemeja a la posición de los pulmones. Aquí cabe destacar que las anotaciones de opacidades pulmonares en el subset de train (que nuestras predicciones deberían imitar) están etiquetadas abarcando una gran proporción de los pulmones.
#
# Dado que la documentación de Darknet no es exhaustiva, desconocíamos cuál era el código que debíamos revisar. No encontramos ninguna publicación en internet de alguien que se haya encontrado con un problema con la escala aparente de los bounding boxes. Sin embargo, estudiando los archivos de Darknet, dentro de la carpeta *src*, se tiene el archivo *image.c* donde hay está la función *draw_detections_v3* donde se puede acceder a las coordenadas de los bounding boxes y luego, éstas pueden imprimirse. Estudiando los resultados de imprimir las coordenadas de todas las predicciones correspondientes al subset de test, se confirmó nuestra conclusión anterior de que la totalidad de las bounding boxes predecidas no superaban los 700 píxeles de ancho y alto.
#
# Sin embargo, con la orientación de Cande Mosquera, nos dimos cuenta que el hecho de que ninguna de *esas* bounding boxes que estábamos estudiando superase los 700 píxeles no aseguraba que nuestro modelo no pudiese indicar detecciones en el área restante de la imagen.
#
# El ganador de la competencia de Kaggle utilizó un valor de 0,15 para el umbral de la confidencia de una detección. Debido a que encontramos ese dato y con el valor default no se detectaba prácticamente ninguna opacidad, decidimos setearlo el umbral a 0,15. Para testear nuestra teoría que un problema de escalas, redujimos el umbral a cero. Como era de esperarse, se detectaron opacidades a lo largo de toda la imagen, lo cual nos llevó a rechazar nuestra hipótesis original.
#
# Al correr el comando de test para una imagen, se crea de forma automática archivo .jpg en la carpeta de contenidos titulado "predictions.jpg". Se crearon dos funciones que utilizan esta imagen para explorar los resultados obtenidos

# %% [markdown]
# ## PredictandShow
# Esta función imprime la predicción de la red (predictions.jpg) para una imagen dada (dirección de google drive) junto a la imagen original. El mejor mAP en validation corresponde a 6000 iteraciones de entrenamiento, seguido por 9000. Se observaron los resultados obtenidos con estas dos instancias de entrenamiento, con las de 12000 y con last_weights. Los mejores resultados se obtuvieron con 9k, por lo que se utilizaron estos pesos a partir de entonces.

# %%
def PredictandShow(image_loc):
  original_img = cv2.imread(image_loc)
  original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
  result = !./darknet detector test '$objdata' '$yolov3cfg' '$weights9k' '$image_loc' -thresh 0.15 -dont_show
  print(result[-1])
  confidence = ''
  if(('Lung Opacity' in result[-1]) & ('%' in result[-1])):
    confidence = result[-1]
  
  fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))                 
  newImage = cv2.imread('predictions.jpg')
  new_img = cv2.cvtColor(newImage, cv2.COLOR_BGR2RGB)
  ax[0].imshow(original_img)
  ax[0].axis('off')
  ax[1].imshow(new_img)
  ax[1].axis('off')
  ax[1].set_title(confidence, fontsize=30, color="green")

# %% [markdown]
# Los resultados que se presentan a continuación corresponden a las imágenes del subset de test, cuyas anotaciones no disponíamos. Debido a que no se consiguió obtener un score no nulo con la Late Submission, no se podían calcular métricas para evaluar el desempeño del modelo en el subset de test y se prosiguió a estudiar los resultados obtenidos visualmente. Se observó que como mucho habían dos opacidades por imagen y su forma se asemeja a la de los pulmones de la imagen, solo que de menor tamaño y ubicados en la esquina superior izquierda.

# %%
PredictandShow('/content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/a3dda87f-1087-42ee-b602-453eaac55e5f.jpg')
# Out:
# /content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng/data/obj/a3dda87f-1087-42ee-b602-453eaac55e5f.jpg: Predicted in 28.017000 milli-seconds.

# %% [markdown]
# ## Actual versus Predict
# Esta función solo puede utilizarse con imágenes etiquetadas. En este caso, no se puede acceder a las etiquetas de las imágenes de test ya que RSNA no las comparte. Por esto no se puede utilizar con imágenes de test. Se muestran los resultados obtenidos con imágenes de validation. En la misma imagen, se presenta la predicción del modelo como recuadros color rosa y las anotaciones de los profesionales como recuadros verdes.

# %%
def ActualvsPredict(patientid):
  image_loc = '/content/drive/My Drive/Final_redes/Notebooks/DarkNet-kriyeng-imagenes1024/dataContainer/data/obj/'+patientId+'.jpg'
  result = !./darknet detector test '$objdata' '$yolov3cfg' '$weights9k' '$image_loc' -thresh 0.15 -dont_show
  print(result)
                   
  newImage = cv2.imread('predictions.jpg')
  newImage = cv2.cvtColor(newImage, cv2.COLOR_BGR2RGB)
  #add axes to the image
  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  ax.axis('off')

  # read and plot the image
  annotations = pd.read_csv('/content/drive/My Drive/Final_redes/RN__TP_Final/stage_2_train_labels.csv')
  image = newImage
  plt.imshow(image)

  # iterating over the image for different objects
  for index,row in annotations[annotations.patientId == image_patientid].iterrows():
            
      edgecolor = 'g'
      ax.annotate('Annotated', xy=(row.x-40,row.y+20))
          
      # add bounding boxes to the image
      rect = patches.Rectangle((row.x,row.y), row.width, row.height, edgecolor = edgecolor, facecolor = 'none')
      
      ax.add_patch(rect)
